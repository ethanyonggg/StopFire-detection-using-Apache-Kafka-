# %%
import pymongo
from pymongo import MongoClient
client = MongoClient('10.192.96.162', 27017)

# %% [markdown]
# ## Task 01
# - Based on the two datasets provided hotspot_historic.csv and climate_historic.csv, a suitable datamodel to support the efficient querying of the two datasets in MongoDB would be to Embed both the documents together
#
# - Looking at the climate history and the hotspot history csv we can see that we can join embed both of these csv files by their dates
#
# - Each station would record the climate data for a set time interval everyday, the climate data would include variables such as air_temperature, relative_humidity, winspeedknots, max_wind_speed and precipitation
#
# - Each station would have 0 or more hotspots and would each hotspot record would have the time or record, latitude, longitude, confidence and the surface_temperature_celsius.
#
# - By embedding climate and hotspot we can retrieve the all date records of the recorded station before it switches to another station and from this we can also view the all hotspots and their relevant details such as the precise location and time
#
# - By fetching a single document this is more efficient that performing mutliple queries across separate collections or requiring join algroithms

# %% [markdown]
# ``` python
# {'GHI_w/m2': 177,
#   'air_temperature_celcius': 21,
#   'date': Timestamp('2023-08-03 00:00:00'),
#   'hotspots': [{'confidence': 68,
#                 'datetime': Timestamp('2023-03-08 04:51:00'),
#                 'latitude': -37.7885,
#                 'longitude': 141.9352,
#                 'surface_temperature_celsius': 55},
#                {'confidence': 75,
#                 'datetime': Timestamp('2023-03-08 00:30:30'),
#                 'latitude': -38.1031,
#                 'longitude': 142.4797,
#                 'surface_temperature_celsius': 48}],
#   'max_wind_speed': 13.0,
#   'precipitation_type': 'I',
#   'precipitation_value': 0.0,
#   'relative_humidity': 51.7,
#   'station': 948701,
#   'windspeed_knots': 7.2}
#  ```

# %% [markdown]
# ## Task 2.1
# - First read both the files having the sperator as a comma since it is a csv file, next format the date for both dataframes to appropriate date time format
# - Precipitation is actually a string type value so I made two new columns called "precipitation_value" and "precipitation_type" to seperate the string
# - The value is set to numeric and the original precipitate column is dropped
# - Both dataframes are then converted to dictionary format

# %%
import pandas as pd
# read the csv delimited by the comma as the seperator
climate_csv = pd.read_csv("./climate_historic.csv", sep=",")
# create date time column using date column from csv and setting date time data type
climate_csv['date'] = pd.to_datetime(climate_csv['date'])

# seperates the string into precipitation value and type
climate_csv[['precipitation_value', 'precipitation_type']] = climate_csv['precipitation'].str.extract(r'(\d+\.?\d*)(\D+)')
# convert to numeric data type
climate_csv['precipitation_value'] = pd.to_numeric(climate_csv['precipitation_value'], errors='coerce')
# drop the precipitaion column since it already has been processed
climate_csv = climate_csv.drop('precipitation', axis=1)

# create climate dictionary
climate_dict = climate_csv.to_dict(orient='records')
print(climate_dict)


hotspot_csv = pd.read_csv("./hotspot_historic.csv", sep=",")
# convert to date 
hotspot_csv['date'] = pd.to_datetime(hotspot_csv['date'])
# convert to date time data type value
hotspot_csv['datetime'] = pd.to_datetime(hotspot_csv['datetime'], format='%Y-%m-%d %H:%M:%S')
print(hotspot_csv['datetime'].iloc[0])
# create hotspot dictionary, where each column would be a key in the dictionary
hotspot_dict = hotspot_csv.to_dict(orient='records')
print(hotspot_dict)
# Out:
# [{'station': 948700, 'date': Timestamp('2022-12-31 00:00:00'), 'air_temperature_celcius': 19, 'relative_humidity': 56.8, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'GHI_w/m2': 154, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-02-01 00:00:00'), 'air_temperature_celcius': 15, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'GHI_w/m2': 128, 'precipitation_value': 0.02, 'precipitation_type': 'G'}, {'station': 948700, 'date': Timestamp('2023-03-01 00:00:00'), 'air_temperature_celcius': 16, 'relative_humidity': 53.6, 'windspeed_knots': 8.1, 'max_wind_speed': 15.0, 'GHI_w/m2': 133, 'precipitation_value': 0.0, 'precipitation_type': 'G'}, {'station': 948700, 'date': Timestamp('2023-04-01 00:00:00'), 'air_temperature_celcius': 24, 'relative_humidity': 61.6, 'windspeed_knots': 7.7, 'max_wind_speed': 14.0, 'GHI_w/m2': 186, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-05-01 00:00:00'), 'air_temperature_celcius': 24, 'relative_humidity': 62.3, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'GHI_w/m2': 185, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-06-01 00:00:00'), 'air_temperature_celcius': 26, 'relative_humidity': 60.8, 'windspeed_knots': 6.9, 'max_wind_speed': 12.0, 'GHI_w/m2': 203, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-07-01 00:00:00'), 'air_temperature_celcius': 32, 'relative_humidity': 54.1, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'GHI_w/m2': 265, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-08-01 00:00:00'), 'air_temperature_celcius': 20, 'relative_humidity': 57.7, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'GHI_w/m2': 160, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-09-01 00:00:00'), 'air_temperature_celcius': 19, 'relative_humidity': 56.3, 'windspeed_knots': 5.8, 'max_wind_speed': 8.9, 'GHI_w/m2': 154, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-10-01 00:00:00'), 'air_temperature_celcius': 20, 'relative_humidity': 57.0, 'windspeed_knots': 8.7, 'max_wind_speed': 13.0, 'GHI_w/m2': 161, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-11-01 00:00:00'), 'air_temperature_celcius': 18, 'relative_humidity': 53.3, 'windspeed_knots': 7.9, 'max_wind_speed': 14.0, 'GHI_w/m2': 150, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-12-01 00:00:00'), 'air_temperature_celcius': 22, 'relative_humidity': 56.3, 'windspeed_knots': 8.0, 'max_wind_speed': 13.0, 'GHI_w/m2': 179, 'precipitation_value': 0.08, 'precipitation_type': 'G'}, {'station': 948700, 'date': Timestamp('2023-01-13 00:00:00'), 'air_temperature_celcius': 19, 'relative_humidity': 54.1, 'windspeed_knots': 11.2, 'max_wind_speed': 18.1, 'GHI_w/m2': 157, 'precipitation_value': 0.31, 'precipitation_type': 'G'}, {'station': 948700, 'date': Timestamp('2023-01-14 00:00:00'), 'air_temperature_celcius': 17, 'relative_humidity': 50.4, 'windspeed_knots': 11.9, 'max_wind_speed': 16.9, 'GHI_w/m2': 145, 'precipitation_value': 0.0, 'precipitation_type': 'G'}, {'station': 948700, 'date': Timestamp('2023-01-15 00:00:00'), 'air_temperature_celcius': 16, 'relative_humidity': 50.8, 'windspeed_knots': 5.8, 'max_wind_speed': 12.0, 'GHI_w/m2': 136, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-01-16 00:00:00'), 'air_temperature_celcius': 24, 'relative_humidity': 55.4, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'GHI_w/m2': 196, 'precipitation_value': 0.0, 'precipitation_type': 'I'}, {'station': 948700, 'date': Timestamp('2023-01-17 00:00:00'), 'air_temperature_celcius': 24, 'relative_humidity': 53.4, 'windspeed_knots':  ...
# 2023-12-27 04:16:51
# [{'latitude': -37.966, 'longitude': 145.051, 'datetime': Timestamp('2023-12-27 04:16:51'), 'confidence': 78, 'date': Timestamp('2023-12-27 00:00:00'), 'surface_temperature_celcius': 68}, {'latitude': -35.541, 'longitude': 143.311, 'datetime': Timestamp('2023-12-27 00:02:15'), 'confidence': 82, 'date': Timestamp('2023-12-27 00:00:00'), 'surface_temperature_celcius': 63}, {'latitude': -35.554, 'longitude': 143.307, 'datetime': Timestamp('2023-12-27 00:02:15'), 'confidence': 67, 'date': Timestamp('2023-12-27 00:00:00'), 'surface_temperature_celcius': 53}, {'latitude': -35.543, 'longitude': 143.316, 'datetime': Timestamp('2023-12-27 00:02:14'), 'confidence': 86, 'date': Timestamp('2023-12-27 00:00:00'), 'surface_temperature_celcius': 67}, {'latitude': -37.708, 'longitude': 145.1, 'datetime': Timestamp('2023-12-25 04:29:08'), 'confidence': 80, 'date': Timestamp('2023-12-25 00:00:00'), 'surface_temperature_celcius': 54}, {'latitude': -35.646, 'longitude': 142.282, 'datetime': Timestamp('2023-12-24 13:12:01'), 'confidence': 65, 'date': Timestamp('2023-12-24 00:00:00'), 'surface_temperature_celcius': 32}, {'latitude': -38.075, 'longitude': 143.76, 'datetime': Timestamp('2023-12-21 04:53:29'), 'confidence': 72, 'date': Timestamp('2023-12-21 00:00:00'), 'surface_temperature_celcius': 46}, {'latitude': -37.636, 'longitude': 149.33, 'datetime': Timestamp('2023-12-16 15:38:39'), 'confidence': 94, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 43}, {'latitude': -37.624, 'longitude': 149.332, 'datetime': Timestamp('2023-12-16 15:38:39'), 'confidence': 69, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 33}, {'latitude': -37.82, 'longitude': 142.323, 'datetime': Timestamp('2023-12-16 04:35:15'), 'confidence': 62, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 54}, {'latitude': -37.875, 'longitude': 142.51, 'datetime': Timestamp('2023-12-16 04:35:13'), 'confidence': 93, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 73}, {'latitude': -37.608, 'longitude': 149.328, 'datetime': Timestamp('2023-12-16 04:34:58'), 'confidence': 84, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 55}, {'latitude': -37.613, 'longitude': 149.305, 'datetime': Timestamp('2023-12-16 04:34:58'), 'confidence': 95, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 75}, {'latitude': -37.644, 'longitude': 149.346, 'datetime': Timestamp('2023-12-16 04:34:57'), 'confidence': 59, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 55}, {'latitude': -37.624, 'longitude': 149.314, 'datetime': Timestamp('2023-12-16 04:34:57'), 'confidence': 90, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 66}, {'latitude': -37.661, 'longitude': 149.327, 'datetime': Timestamp('2023-12-16 04:34:57'), 'confidence': 75, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 56}, {'latitude': -37.649, 'longitude': 149.322, 'datetime': Timestamp('2023-12-16 04:34:57'), 'confidence': 79, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 60}, {'latitude': -38.057, 'longitude': 144.211, 'datetime': Timestamp('2023-12-16 00:21:12'), 'confidence': 93, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 73}, {'latitude': -38.046, 'longitude': 144.201, 'datetime': Timestamp('2023-12-16 00:21:11'), 'confidence': 60, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 48}, {'latitude': -38.048, 'longitude': 144.213, 'datetime': Timestamp('2023-12-16 00:21:11'), 'confidence': 82, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 55}, {'latitude': -37.651, 'longitude': 149.345, 'datetime': Timestamp('2023-12-16 00:20:53'), 'confidence': 82, 'date': Timestamp('2023-12-16 00:00:00'), 'surface_temperature_celcius': 64}, {'latitude': -37.63, 'longitude': 149.335, 'datetime': Timestamp('2023-12-16 00:20:53'), 'confidenc ...
# /tmp/ipykernel_66372/1756324149.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   climate_csv['date'] = pd.to_datetime(climate_csv['date'])
# /tmp/ipykernel_66372/1756324149.py:14: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   hotspot_csv['date'] = pd.to_datetime(hotspot_csv['date'])

# %% [markdown]
# ## Task 2.2

# %% [markdown]
# ## Task 2.2a
# - Finidng all climate data on 12th December 2023

# %%
collections = collection.find()
for tour in collections:
    pprint(tour)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e0'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e1'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 2, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e2'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 3, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e3'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 4, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e4'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 5, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e5'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 6, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e6'),
#  'air_temperature_celcius': 32,
#  'date': datetime.datetime(2023, 7, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e7'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 8, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e8'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 9, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e9'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 10, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ea'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 11, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.3,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 179,
#  '_id': ObjectId('6650a2f9f374f529b6ea16eb'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 12, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.08,
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 157,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ec'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 1, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ed'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 1, 14, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 50.4,
#  'station': 948700,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ee'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ef'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 1, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.4,
#  'station': 948700,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 200,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f0'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 1, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f1'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 46.7,
#  'station': 948700,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f2'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 1, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.98,
#  'relative_humidity': 57.2,
#  'station': 948700,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f3'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.03,
#  'relative_humidity': 50.9,
#  'station': 948700,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f4'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 1, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.5,
#  'station': 948700,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 182,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f5'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 1, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 59.0,
#  'station': 948700,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f6'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2023, 1, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.04,
#  'relative_humidity': 58.3,
#  'station': 948700,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f7'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 24, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 48.2,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f8'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 1, 25, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea16f9'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 1, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.5,
#  'station': 948700,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6650a2f9f374f529b6ea16fa'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 1, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'A',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.1,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6650a2f9f374f529b6ea16fb'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 1, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('6650a2f9f374f529b6ea16fc'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 1, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.0,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('6650a2f9f374f529b6ea16fd'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 1, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 55.8,
#  'station': 948700,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6650a2f9f374f529b6ea16fe'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.4,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 138,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ff'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 1, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.9,
#  'station': 948700,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea1700'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 2, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.0,
#  'station': 948700,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('6650a2f9f374f529b6ea1701'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 3, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.4,
#  'station': 948700,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('6650a2f9f374f529b6ea1702'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 4, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6650a2f9f374f529b6ea1703'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 5, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 1.26,
#  'relative_humidity': 64.5,
#  'station': 948700,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6650a2f9f374f529b6ea1704'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 6, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.1,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6650a2f9f374f529b6ea1705'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 7, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 239,
#  '_id': ObjectId('6650a2f9f374f529b6ea1706'),
#  'air_temperature_celcius': 31,
#  'date': datetime.datetime(2023, 8, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 23.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.9,
#  'station': 948700,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6650a2f9f374f529b6ea1707'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 9, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.7,
#  'station': 948700,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 164,
#  '_id': ObjectId('6650a2f9f374f529b6ea1708'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 10, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.4,
#  'station': 948700,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6650a2f9f374f529b6ea1709'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 11, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 53.8,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6650a2f9f374f529b6ea170a'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 12, 2, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.3,
#  'station': 948700,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6650a2f9f374f529b6ea170b'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 2, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.16,
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6650a2f9f374f529b6ea170c'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2023, 2, 14, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('6650a2f9f374f529b6ea170d'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 2, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea170e'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 2, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6650a2f9f374f529b6ea170f'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 2, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 49.4,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('6650a2f9f374f529b6ea1710'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 2, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 44.6,
#  'station': 948700,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('6650a2f9f374f529b6ea1711'),
#  'air_temperature_celcius': 13,
#  'date': datetime.datetime(2023, 2, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.71,
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('6650a2f9f374f529b6ea1712'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 2, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 49.1,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('6650a2f9f374f529b6ea1713'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 2, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('6650a2f9f374f529b6ea1714'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 2, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 49.6,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6650a2f9f374f529b6ea1715'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 2, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('6650a2f9f374f529b6ea1716'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 2, 24, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 48.3,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6650a2f9f374f529b6ea1717'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 2, 25, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.6,
#  'station': 948701,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 173,
#  '_id': ObjectId('6650a2f9f374f529b6ea1718'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 2, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('6650a2f9f374f529b6ea1719'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 2, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 190,
#  '_id': ObjectId('6650a2f9f374f529b6ea171a'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 2, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.1,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6650a2f9f374f529b6ea171b'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 1, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 9.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.3,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6650a2f9f374f529b6ea171c'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 2, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('6650a2f9f374f529b6ea171d'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 3, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 59.5,
#  'station': 948701,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('6650a2f9f374f529b6ea171e'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 4, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6650a2f9f374f529b6ea171f'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 5, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.8,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('6650a2f9f374f529b6ea1720'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 6, 3, 0, 0),
#  'hotspots': [{'confidence': 87,
#                'datetime': datetime.datetime(2023, 3, 6, 5, 6, 30),
#                'latitude': -34.3795,
#                'longitude': 141.6331,
#                'surface_temperature_celsius': 62},
#               {'confidence': 85,
#                'datetime': datetime.datetime(2023, 3, 6, 5, 6, 20),
#                'latitude': -34.3735,
#                'longitude': 141.6604,
#                'surface_temperature_celsius': 59}],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.9,
#  'station': 948701,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6650a2f9f374f529b6ea1721'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 7, 3, 0, 0),
#  'hotspots': [{'confidence': 88,
#                'datetime': datetime.datetime(2023, 3, 7, 4, 16, 10),
#                'latitude': -37.7752,
#                'longitude': 141.9086,
#                'surface_temperature_celsius': 64}],
#  'max_wind_speed': 20.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 51.5,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 177,
#  '_id': ObjectId('6650a2f9f374f529b6ea1722'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 8, 3, 0, 0),
#  'hotspots': [{'confidence': 68,
#                'datetime': datetime.datetime(2023, 3, 8, 4, 51),
#                'latitude': -37.7885,
#                'longitude': 141.9352,
#                'surface_temperature_celsius': 55},
#               {'confidence': 75,
#                'datetime': datetime.datetime(2023, 3, 8, 0, 30, 30),
#                'latitude': -38.1031,
#                'longitude': 142.4797,
#                'surface_temperature_celsius': 48}],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('6650a2f9f374f529b6ea1723'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 9, 3, 0, 0),
#  'hotspots': [{'confidence': 86,
#                'datetime': datetime.datetime(2023, 3, 9, 13, 23, 40),
#                'latitude': -37.996,
#                'longitude': 146.3535,
#                'surface_temperature_celsius': 41},
#               {'confidence': 54,
#                'datetime': datetime.datetime(2023, 3, 9, 3, 57),
#                'latitude': -37.7171,
#                'longitude': 147.5866,
#                'surface_temperature_celsius': 44},
#               {'confidence': 78,
#                'datetime': datetime.datetime(2023, 3, 9, 3, 56, 50),
#                'latitude': -37.7074,
#                'longitude': 147.5849,
#                'surface_temperature_celsius': 55}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('6650a2f9f374f529b6ea1724'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 10, 3, 0, 0),
#  'hotspots': [{'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 48, 40),
#                'latitude': -37.223,
#                'longitude': 147.9431,
#                'surface_temperature_celsius': 105},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 46, 20),
#                'latitude': -37.2252,
#                'longitude': 147.9363,
#                'surface_temperature_celsius': 109},
#               {'confidence': 94,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 45, 30),
#                'latitude': -37.2284,
#                'longitude': 147.9187,
#                'surface_temperature_celsius': 73},
#               {'confidence': 97,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 45, 30),
#                'latitude': -37.6572,
#                'longitude': 142.0703,
#                'surface_temperature_celsius': 80},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 43, 50),
#                'latitude': -37.6592,
#                'longitude': 142.058,
#                'surface_temperature_celsius': 55},
#               {'confidence': 55,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 43),
#                'latitude': -36.2544,
#                'longitude': 148.0353,
#                'surface_temperature_celsius': 42},
#               {'confidence': 54,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 42, 30),
#                'latitude': -37.2197,
#                'longitude': 147.9621,
#                'surface_temperature_celsius': 43},
#               {'confidence': 74,
#                'datetime': datetime.datetime(2023, 3, 10, 4, 39),
#                'latitude': -37.2128,
#                'longitude': 147.9308,
#                'surface_temperature_celsius': 48}],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6650a2f9f374f529b6ea1725'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 11, 3, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.01,
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 168,
#  '_id': ObjectId('6650a2f9f374f529b6ea1726'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 12, 3, 0, 0),
#  'hotspots': [{'confidence': 94,
#                'datetime': datetime.datetime(2023, 3, 12, 4, 33, 50),
#                'latitude': -37.4157,
#                'longitude': 147.0084,
#                'surface_temperature_celsius': 105},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 3, 12, 4, 29, 50),
#                'latitude': -37.0193,
#                'longitude': 148.1459,
#                'surface_temperature_celsius': 71},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 12, 4, 28, 20),
#                'latitude': -37.4229,
#                'longitude': 147.027,
#                'surface_temperature_celsius': 99},
#               {'confidence': 80,
#                'datetime': datetime.datetime(2023, 3, 12, 4, 28),
#                'latitude': -37.0055,
#                'longitude': 148.1582,
#                'surface_temperature_celsius': 68},
#               {'confidence': 85,
#                'datetime': datetime.datetime(2023, 3, 12, 4, 27, 20),
#                'latitude': -37.4128,
#                'longitude': 147.0242,
#                'surface_temperature_celsius': 98}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea1727'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 3, 13, 0, 0),
#  'hotspots': [{'confidence': 56,
#                'datetime': datetime.datetime(2023, 3, 13, 23, 58, 50),
#                'latitude': -37.0286,
#                'longitude': 148.155,
#                'surface_temperature_celsius': 42},
#               {'confidence': 52,
#                'datetime': datetime.datetime(2023, 3, 13, 12, 57),
#                'latitude': -37.0316,
#                'longitude': 148.1519,
#                'surface_temperature_celsius': 35}],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('6650a2f9f374f529b6ea1728'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2023, 3, 14, 0, 0),
#  'hotspots': [{'confidence': 90,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 24, 40),
#                'latitude': -34.357,
#                'longitude': 141.5361,
#                'surface_temperature_celsius': 67},
#               {'confidence': 93,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 22, 20),
#                'latitude': -34.3539,
#                'longitude': 141.5547,
#                'surface_temperature_celsius': 72},
#               {'confidence': 90,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 20, 50),
#                'latitude': -36.9939,
#                'longitude': 148.2244,
#                'surface_temperature_celsius': 68},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 19, 30),
#                'latitude': -36.998,
#                'longitude': 148.1994,
#                'surface_temperature_celsius': 48},
#               {'confidence': 95,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 16, 30),
#                'latitude': -36.9959,
#                'longitude': 148.2118,
#                'surface_temperature_celsius': 75},
#               {'confidence': 89,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 16, 20),
#                'latitude': -34.3654,
#                'longitude': 141.543,
#                'surface_temperature_celsius': 65},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 14, 40),
#                'latitude': -37.0228,
#                'longitude': 148.1996,
#                'surface_temperature_celsius': 52},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 14, 40),
#                'latitude': -34.3539,
#                'longitude': 141.5629,
#                'surface_temperature_celsius': 55},
#               {'confidence': 96,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 14, 30),
#                'latitude': -34.3554,
#                'longitude': 141.5413,
#                'surface_temperature_celsius': 79},
#               {'confidence': 94,
#                'datetime': datetime.datetime(2023, 3, 14, 4, 14, 30),
#                'latitude': -34.3555,
#                'longitude': 141.5495,
#                'surface_temperature_celsius': 75}],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.3,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6650a2f9f374f529b6ea1729'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2023, 3, 15, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'datetime': datetime.datetime(2023, 3, 15, 5, 2),
#                'latitude': -37.4108,
#                'longitude': 147.0196,
#                'surface_temperature_celsius': 50},
#               {'confidence': 74,
#                'datetime': datetime.datetime(2023, 3, 15, 4, 59, 10),
#                'latitude': -37.4058,
#                'longitude': 147.0117,
#                'surface_temperature_celsius': 48},
#               {'confidence': 52,
#                'datetime': datetime.datetime(2023, 3, 15, 0, 42, 50),
#                'latitude': -37.4075,
#                'longitude': 147.0233,
#                'surface_temperature_celsius': 43},
#               {'confidence': 66,
#                'datetime': datetime.datetime(2023, 3, 15, 0, 42, 50),
#                'latitude': -37.0228,
#                'longitude': 148.1281,
#                'surface_temperature_celsius': 43},
#               {'confidence': 51,
#                'datetime': datetime.datetime(2023, 3, 15, 0, 42, 40),
#                'latitude': -37.002,
#                'longitude': 148.2055,
#                'surface_temperature_celsius': 44},
#               {'confidence': 75,
#                'datetime': datetime.datetime(2023, 3, 15, 0, 38, 10),
#                'latitude': -37.0249,
#                'longitude': 148.1561,
#                'surface_temperature_celsius': 49},
#               {'confidence': 70,
#                'datetime': datetime.datetime(2023, 3, 15, 0, 37, 20),
#                'latitude': -37.4098,
#                'longitude': 147.0489,
#                'surface_temperature_celsius': 45}],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.04,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea172a'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 3, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.3,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('6650a2f9f374f529b6ea172b'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 3, 17, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 48, 20),
#                'latitude': -34.3383,
#                'longitude': 141.543,
#                'surface_temperature_celsius': 56},
#               {'confidence': 94,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 48, 20),
#                'latitude': -36.7152,
#                'longitude': 141.3853,
#                'surface_temperature_celsius': 74},
#               {'confidence': 78,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 46, 40),
#                'latitude': -34.328,
#                'longitude': 141.5402,
#                'surface_temperature_celsius': 58},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 45, 10),
#                'latitude': -36.6867,
#                'longitude': 141.137,
#                'surface_temperature_celsius': 59},
#               {'confidence': 76,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 45),
#                'latitude': -36.6889,
#                'longitude': 141.1239,
#                'surface_temperature_celsius': 50},
#               {'confidence': 86,
#                'datetime': datetime.datetime(2023, 3, 17, 4, 45),
#                'latitude': -36.7128,
#                'longitude': 141.3986,
#                'surface_temperature_celsius': 60}],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('6650a2f9f374f529b6ea172c'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 3, 18, 0, 0),
#  'hotspots': [{'confidence': 64,
#                'datetime': datetime.datetime(2023, 3, 18, 13, 16, 50),
#                'latitude': -37.4313,
#                'longitude': 147.0343,
#                'surface_temperature_celsius': 37},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 18, 3, 50, 50),
#                'latitude': -37.017,
#                'longitude': 148.1297,
#                'surface_temperature_celsius': 121},
#               {'confidence': 97,
#                'datetime': datetime.datetime(2023, 3, 18, 3, 50, 40),
#                'latitude': -37.0155,
#                'longitude': 148.1432,
#                'surface_temperature_celsius': 80}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('6650a2f9f374f529b6ea172d'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'hotspots': [{'confidence': 85,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 39, 50),
#                'latitude': -37.6605,
#                'longitude': 142.1116,
#                'surface_temperature_celsius': 60},
#               {'confidence': 58,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 39, 20),
#                'latitude': -37.9164,
#                'longitude': 143.4866,
#                'surface_temperature_celsius': 54},
#               {'confidence': 96,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 39, 20),
#                'latitude': -37.6622,
#                'longitude': 142.1001,
#                'surface_temperature_celsius': 79},
#               {'confidence': 63,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 39, 20),
#                'latitude': -37.9257,
#                'longitude': 143.4891,
#                'surface_temperature_celsius': 54},
#               {'confidence': 64,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 36),
#                'latitude': -37.3982,
#                'longitude': 147.0001,
#                'surface_temperature_celsius': 58},
#               {'confidence': 90,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 36),
#                'latitude': -37.4523,
#                'longitude': 147.0175,
#                'surface_temperature_celsius': 66},
#               {'confidence': 59,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 35),
#                'latitude': -37.4023,
#                'longitude': 147.0394,
#                'surface_temperature_celsius': 56},
#               {'confidence': 60,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 33, 50),
#                'latitude': -37.4336,
#                'longitude': 147.0534,
#                'surface_temperature_celsius': 51},
#               {'confidence': 61,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 33, 30),
#                'latitude': -37.4003,
#                'longitude': 147.0448,
#                'surface_temperature_celsius': 55},
#               {'confidence': 53,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 33, 30),
#                'latitude': -37.9184,
#                'longitude': 143.4745,
#                'surface_temperature_celsius': 55},
#               {'confidence': 61,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 33, 10),
#                'latitude': -37.3911,
#                'longitude': 147.037,
#                'surface_temperature_celsius': 50},
#               {'confidence': 98,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 33),
#                'latitude': -37.4261,
#                'longitude': 147.0323,
#                'surface_temperature_celsius': 83},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 50),
#                'latitude': -37.3949,
#                'longitude': 147.0175,
#                'surface_temperature_celsius': 91},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 50),
#                'latitude': -37.671,
#                'longitude': 144.6536,
#                'surface_temperature_celsius': 58},
#               {'confidence': 66,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 50),
#                'latitude': -37.9277,
#                'longitude': 143.477,
#                'surface_temperature_celsius': 55},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 40),
#                'latitude': -37.4224,
#                'longitude': 147.0511,
#                'surface_temperature_celsius': 113},
#               {'confidence': 92,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 40),
#                'latitude': -37.6625,
#                'longitude': 144.287,
#                'surface_temperature_celsius': 70},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 40),
#                'latitude': -37.4375,
#                'longitude': 147.0336,
#                'surface_temperature_celsius': 106},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 3, 19, 4, 32, 40),
#                'latitude': -37.4414,
#                'longitude': 147.0139,
#                'surface_temperature_celsius': 60},
#               {'confidence': 77,
#                'datetime': datetime.datetime(2023, 3, 19, 0, 15, 50),
#                'latitude': -37.4295,
#                'longitude': 147.0428,
#                'surface_temperature_celsius': 59},
#               {'confidence': 60,
#                'datetime': datetime.datetime(2023, 3, 19, 0, 12, 50),
#                'latitude': -37.3942,
#                'longitude': 147.0455,
#                'surface_temperature_celsius': 44}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 174,
#  '_id': ObjectId('6650a2f9f374f529b6ea172e'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 3, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.08,
#  'relative_humidity': 63.8,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6650a2f9f374f529b6ea172f'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 3, 21, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.63,
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6650a2f9f374f529b6ea1730'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 3, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.5,
#  'station': 948701,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('6650a2f9f374f529b6ea1731'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 3, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6650a2f9f374f529b6ea1732'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 3, 24, 0, 0),
#  'hotspots': [{'confidence': 65,
#                'datetime': datetime.datetime(2023, 3, 24, 4, 58),
#                'latitude': -37.1603,
#                'longitude': 142.8088,
#                'surface_temperature_celsius': 50},
#               {'confidence': 55,
#                'datetime': datetime.datetime(2023, 3, 24, 4, 56, 10),
#                'latitude': -37.1684,
#                'longitude': 142.8183,
#                'surface_temperature_celsius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('6650a2f9f374f529b6ea1733'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 3, 25, 0, 0),
#  'hotspots': [{'confidence': 76,
#                'datetime': datetime.datetime(2023, 3, 25, 4, 3, 10),
#                'latitude': -37.8025,
#                'longitude': 145.8702,
#                'surface_temperature_celsius': 49},
#               {'confidence': 62,
#                'datetime': datetime.datetime(2023, 3, 25, 4, 3, 10),
#                'latitude': -37.8992,
#                'longitude': 143.4534,
#                'surface_temperature_celsius': 54},
#               {'confidence': 78,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 59, 50),
#                'latitude': -37.8758,
#                'longitude': 145.8371,
#                'surface_temperature_celsius': 52},
#               {'confidence': 82,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 59, 50),
#                'latitude': -37.8973,
#                'longitude': 143.4754,
#                'surface_temperature_celsius': 65},
#               {'confidence': 87,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 58, 10),
#                'latitude': -37.7829,
#                'longitude': 143.5056,
#                'surface_temperature_celsius': 62},
#               {'confidence': 95,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 58, 10),
#                'latitude': -37.7805,
#                'longitude': 143.5003,
#                'surface_temperature_celsius': 75},
#               {'confidence': 85,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 57, 10),
#                'latitude': -37.5629,
#                'longitude': 144.752,
#                'surface_temperature_celsius': 59},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 57, 10),
#                'latitude': -37.8122,
#                'longitude': 146.0807,
#                'surface_temperature_celsius': 111},
#               {'confidence': 95,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 57, 10),
#                'latitude': -37.8774,
#                'longitude': 145.8213,
#                'surface_temperature_celsius': 77},
#               {'confidence': 75,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 56, 50),
#                'latitude': -37.5742,
#                'longitude': 144.7536,
#                'surface_temperature_celsius': 49},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 56, 40),
#                'latitude': -37.8881,
#                'longitude': 145.8229,
#                'surface_temperature_celsius': 99},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 56, 40),
#                'latitude': -37.5612,
#                'longitude': 144.7701,
#                'surface_temperature_celsius': 49},
#               {'confidence': 57,
#                'datetime': datetime.datetime(2023, 3, 25, 3, 56, 40),
#                'latitude': -37.9022,
#                'longitude': 143.4607,
#                'surface_temperature_celsius': 57}],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('6650a2f9f374f529b6ea1734'),
#  'air_temperature_celcius': 23,
#  'date': datetime.datetime(2023, 3, 26, 0, 0),
#  'hotspots': [{'confidence': 74,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 47, 20),
#                'latitude': -37.665,
#                'longitude': 142.1339,
#                'surface_temperature_celsius': 48},
#               {'confidence': 74,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 43, 40),
#                'latitude': -38.0564,
#                'longitude': 142.8525,
#                'surface_temperature_celsius': 48},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 43, 20),
#                'latitude': -38.018,
#                'longitude': 143.899,
#                'surface_temperature_celsius': 54},
#               {'confidence': 68,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 41, 10),
#                'latitude': -38.1131,
#                'longitude': 143.7173,
#                'surface_temperature_celsius': 44},
#               {'confidence': 80,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 40, 50),
#                'latitude': -38.1106,
#                'longitude': 143.7314,
#                'surface_temperature_celsius': 53},
#               {'confidence': 75,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 40, 10),
#                'latitude': -37.8289,
#                'longitude': 145.9315,
#                'surface_temperature_celsius': 49},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 39, 50),
#                'latitude': -38.0652,
#                'longitude': 142.9781,
#                'surface_temperature_celsius': 54},
#               {'confidence': 71,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 39, 10),
#                'latitude': -37.522,
#                'longitude': 143.3874,
#                'surface_temperature_celsius': 73},
#               {'confidence': 91,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 39, 10),
#                'latitude': -38.0674,
#                'longitude': 142.965,
#                'surface_temperature_celsius': 68},
#               {'confidence': 92,
#                'datetime': datetime.datetime(2023, 3, 26, 4, 39, 10),
#                'latitude': -38.0715,
# ...
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 12, 8, 13, 11, 43),
#                'latitude': -36.293,
#                'longitude': 146.148,
#                'surface_temperature_celsius': 52},
#               {'confidence': 56,
#                'datetime': datetime.datetime(2023, 12, 8, 13, 11, 43),
#                'latitude': -36.291,
#                'longitude': 146.159,
#                'surface_temperature_celsius': 40}],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6650a2f9f374f529b6ea1836'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 9, 12, 0, 0),
#  'hotspots': [{'confidence': 87,
#                'datetime': datetime.datetime(2023, 12, 9, 0, 14, 34),
#                'latitude': -36.294,
#                'longitude': 146.149,
#                'surface_temperature_celsius': 61},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 12, 9, 0, 14, 34),
#                'latitude': -36.285,
#                'longitude': 146.151,
#                'surface_temperature_celsius': 54},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 12, 9, 0, 14, 33),
#                'latitude': -36.277,
#                'longitude': 146.165,
#                'surface_temperature_celsius': 58},
#               {'confidence': 86,
#                'datetime': datetime.datetime(2023, 12, 9, 0, 14, 33),
#                'latitude': -36.275,
#                'longitude': 146.154,
#                'surface_temperature_celsius': 60}],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6650a2f9f374f529b6ea1837'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 10, 12, 0, 0),
#  'hotspots': [{'confidence': 50,
#                'datetime': datetime.datetime(2023, 12, 10, 0, 57, 59),
#                'latitude': -37.987,
#                'longitude': 144.005,
#                'surface_temperature_celsius': 38},
#               {'confidence': 67,
#                'datetime': datetime.datetime(2023, 12, 10, 0, 56, 57),
#                'latitude': -34.289,
#                'longitude': 141.712,
#                'surface_temperature_celsius': 54}],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6650a2f9f374f529b6ea1838'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 11, 12, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('6650a2f9f374f529b6ea1839'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 12, 12, 0, 0),
#  'hotspots': [{'confidence': 53,
#                'datetime': datetime.datetime(2023, 12, 12, 0, 45, 38),
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celsius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('6650a2f9f374f529b6ea183a'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2023, 12, 13, 0, 0),
#  'hotspots': [{'confidence': 83,
#                'datetime': datetime.datetime(2023, 12, 13, 4, 4, 19),
#                'latitude': -38.231,
#                'longitude': 147.172,
#                'surface_temperature_celsius': 60}],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 49.9,
#  'station': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6650a2f9f374f529b6ea183b'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 12, 14, 0, 0),
#  'hotspots': [{'confidence': 92,
#                'datetime': datetime.datetime(2023, 12, 14, 4, 47, 25),
#                'latitude': -37.95,
#                'longitude': 142.366,
#                'surface_temperature_celsius': 70}],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6650a2f9f374f529b6ea183c'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 12, 15, 0, 0),
#  'hotspots': [{'confidence': 92,
#                'datetime': datetime.datetime(2023, 12, 15, 13, 17, 17),
#                'latitude': -37.627,
#                'longitude': 149.33,
#                'surface_temperature_celsius': 42},
#               {'confidence': 78,
#                'datetime': datetime.datetime(2023, 12, 15, 13, 17, 17),
#                'latitude': -37.658,
#                'longitude': 149.339,
#                'surface_temperature_celsius': 36},
#               {'confidence': 51,
#                'datetime': datetime.datetime(2023, 12, 15, 13, 17, 17),
#                'latitude': -37.623,
#                'longitude': 149.323,
#                'surface_temperature_celsius': 38},
#               {'confidence': 65,
#                'datetime': datetime.datetime(2023, 12, 15, 1, 16, 23),
#                'latitude': -38.038,
#                'longitude': 142.986,
#                'surface_temperature_celsius': 40}],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea183d'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'hotspots': [{'confidence': 94,
#                'datetime': datetime.datetime(2023, 12, 16, 15, 38, 39),
#                'latitude': -37.636,
#                'longitude': 149.33,
#                'surface_temperature_celsius': 43},
#               {'confidence': 69,
#                'datetime': datetime.datetime(2023, 12, 16, 15, 38, 39),
#                'latitude': -37.624,
#                'longitude': 149.332,
#                'surface_temperature_celsius': 33},
#               {'confidence': 62,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 35, 15),
#                'latitude': -37.82,
#                'longitude': 142.323,
#                'surface_temperature_celsius': 54},
#               {'confidence': 93,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 35, 13),
#                'latitude': -37.875,
#                'longitude': 142.51,
#                'surface_temperature_celsius': 73},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 58),
#                'latitude': -37.608,
#                'longitude': 149.328,
#                'surface_temperature_celsius': 55},
#               {'confidence': 95,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 58),
#                'latitude': -37.613,
#                'longitude': 149.305,
#                'surface_temperature_celsius': 75},
#               {'confidence': 59,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 57),
#                'latitude': -37.644,
#                'longitude': 149.346,
#                'surface_temperature_celsius': 55},
#               {'confidence': 90,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 57),
#                'latitude': -37.624,
#                'longitude': 149.314,
#                'surface_temperature_celsius': 66},
#               {'confidence': 75,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 57),
#                'latitude': -37.661,
#                'longitude': 149.327,
#                'surface_temperature_celsius': 56},
#               {'confidence': 79,
#                'datetime': datetime.datetime(2023, 12, 16, 4, 34, 57),
#                'latitude': -37.649,
#                'longitude': 149.322,
#                'surface_temperature_celsius': 60},
#               {'confidence': 93,
#                'datetime': datetime.datetime(2023, 12, 16, 0, 21, 12),
#                'latitude': -38.057,
#                'longitude': 144.211,
#                'surface_temperature_celsius': 73},
#               {'confidence': 60,
#                'datetime': datetime.datetime(2023, 12, 16, 0, 21, 11),
#                'latitude': -38.046,
#                'longitude': 144.201,
#                'surface_temperature_celsius': 48},
#               {'confidence': 82,
#                'datetime': datetime.datetime(2023, 12, 16, 0, 21, 11),
#                'latitude': -38.048,
#                'longitude': 144.213,
#                'surface_temperature_celsius': 55},
#               {'confidence': 82,
#                'datetime': datetime.datetime(2023, 12, 16, 0, 20, 53),
#                'latitude': -37.651,
#                'longitude': 149.345,
#                'surface_temperature_celsius': 64},
#               {'confidence': 53,
#                'datetime': datetime.datetime(2023, 12, 16, 0, 20, 53),
#                'latitude': -37.63,
#                'longitude': 149.335,
#                'surface_temperature_celsius': 57}],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('6650a2f9f374f529b6ea183e'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 12, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('6650a2f9f374f529b6ea183f'),
#  'air_temperature_celcius': 25,
#  'date': datetime.datetime(2023, 12, 18, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.9,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('6650a2f9f374f529b6ea1840'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 12, 19, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 22.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.67,
#  'relative_humidity': 57.4,
#  'station': 948702,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 144,
#  '_id': ObjectId('6650a2f9f374f529b6ea1841'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 12, 20, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 51.2,
#  'station': 948702,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('6650a2f9f374f529b6ea1842'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 12, 21, 0, 0),
#  'hotspots': [{'confidence': 72,
#                'datetime': datetime.datetime(2023, 12, 21, 4, 53, 29),
#                'latitude': -38.075,
#                'longitude': 143.76,
#                'surface_temperature_celsius': 46}],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('6650a2f9f374f529b6ea1843'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 12, 22, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.8,
#  'station': 948702,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('6650a2f9f374f529b6ea1844'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 12, 23, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.9,
#  'station': 948702,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('6650a2f9f374f529b6ea1845'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 12, 24, 0, 0),
#  'hotspots': [{'confidence': 65,
#                'datetime': datetime.datetime(2023, 12, 24, 13, 12, 1),
#                'latitude': -35.646,
#                'longitude': 142.282,
#                'surface_temperature_celsius': 32}],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('6650a2f9f374f529b6ea1846'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 12, 25, 0, 0),
#  'hotspots': [{'confidence': 80,
#                'datetime': datetime.datetime(2023, 12, 25, 4, 29, 8),
#                'latitude': -37.708,
#                'longitude': 145.1,
#                'surface_temperature_celsius': 54}],
#  'max_wind_speed': 16.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 50.4,
#  'station': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('6650a2f9f374f529b6ea1847'),
#  'air_temperature_celcius': 22,
#  'date': datetime.datetime(2023, 12, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('6650a2f9f374f529b6ea1848'),
#  'air_temperature_celcius': 28,
#  'date': datetime.datetime(2023, 12, 27, 0, 0),
#  'hotspots': [{'confidence': 78,
#                'datetime': datetime.datetime(2023, 12, 27, 4, 16, 51),
#                'latitude': -37.966,
#                'longitude': 145.051,
#                'surface_temperature_celsius': 68},
#               {'confidence': 82,
#                'datetime': datetime.datetime(2023, 12, 27, 0, 2, 15),
#                'latitude': -35.541,
#                'longitude': 143.311,
#                'surface_temperature_celsius': 63},
#               {'confidence': 67,
#                'datetime': datetime.datetime(2023, 12, 27, 0, 2, 15),
#                'latitude': -35.554,
#                'longitude': 143.307,
#                'surface_temperature_celsius': 53},
#               {'confidence': 86,
#                'datetime': datetime.datetime(2023, 12, 27, 0, 2, 14),
#                'latitude': -35.543,
#                'longitude': 143.316,
#                'surface_temperature_celsius': 67}],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('6650a2f9f374f529b6ea1849'),
#  'air_temperature_celcius': 21,
#  'date': datetime.datetime(2023, 12, 28, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.1,
#  'station': 948702,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea184a'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 12, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.63,
#  'relative_humidity': 59.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('6650a2f9f374f529b6ea184b'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 12, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 51.5,
#  'station': 948702,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('6650a2f9f374f529b6ea184c'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('6650a2f9f374f529b6ea184d'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2024, 1, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 52.9,
#  'station': 948702,
#  'windspeed_knots': 8.1}

# %%
from datetime import datetime

date = "12/12/23"
# converting it to date format
date = datetime.strptime(date, '%d/%m/%y')

# finding the climate record that has the matching date
pprint(collection.find_one({"date":date}))
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('6650a2f9f374f529b6ea1839'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 12, 12, 0, 0),
#  'hotspots': [{'confidence': 53,
#                'datetime': datetime.datetime(2023, 12, 12, 0, 45, 38),
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celsius': 44}],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# ## Task 2.2b
# - Finding the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
# find records where surface temperature celsius is greater than or equals to 65 and lesser than equals to 100
# display the latitude, longitude, temperature and confidence 
results = collection.find({"hotspots": {"$elemMatch": {"surface_temperature_celsius": {"$gte": 65, "$lte": 100}}}}, {"hotspots.latitude":1, "hotspots.longitude":1, "hotspots.surface_temperature_celsius":1, "hotspots.confidence": 1})

for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('6650a2f9f374f529b6ea1724'),
#  'hotspots': [{'confidence': 100,
#                'latitude': -37.223,
#                'longitude': 147.9431,
#                'surface_temperature_celsius': 105},
#               {'confidence': 100,
#                'latitude': -37.2252,
#                'longitude': 147.9363,
#                'surface_temperature_celsius': 109},
#               {'confidence': 94,
#                'latitude': -37.2284,
#                'longitude': 147.9187,
#                'surface_temperature_celsius': 73},
#               {'confidence': 97,
#                'latitude': -37.6572,
#                'longitude': 142.0703,
#                'surface_temperature_celsius': 80},
#               {'confidence': 81,
#                'latitude': -37.6592,
#                'longitude': 142.058,
#                'surface_temperature_celsius': 55},
#               {'confidence': 55,
#                'latitude': -36.2544,
#                'longitude': 148.0353,
#                'surface_temperature_celsius': 42},
#               {'confidence': 54,
#                'latitude': -37.2197,
#                'longitude': 147.9621,
#                'surface_temperature_celsius': 43},
#               {'confidence': 74,
#                'latitude': -37.2128,
#                'longitude': 147.9308,
#                'surface_temperature_celsius': 48}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1726'),
#  'hotspots': [{'confidence': 94,
#                'latitude': -37.4157,
#                'longitude': 147.0084,
#                'surface_temperature_celsius': 105},
#               {'confidence': 84,
#                'latitude': -37.0193,
#                'longitude': 148.1459,
#                'surface_temperature_celsius': 71},
#               {'confidence': 100,
#                'latitude': -37.4229,
#                'longitude': 147.027,
#                'surface_temperature_celsius': 99},
#               {'confidence': 80,
#                'latitude': -37.0055,
#                'longitude': 148.1582,
#                'surface_temperature_celsius': 68},
#               {'confidence': 85,
#                'latitude': -37.4128,
#                'longitude': 147.0242,
#                'surface_temperature_celsius': 98}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1728'),
#  'hotspots': [{'confidence': 90,
#                'latitude': -34.357,
#                'longitude': 141.5361,
#                'surface_temperature_celsius': 67},
#               {'confidence': 93,
#                'latitude': -34.3539,
#                'longitude': 141.5547,
#                'surface_temperature_celsius': 72},
#               {'confidence': 90,
#                'latitude': -36.9939,
#                'longitude': 148.2244,
#                'surface_temperature_celsius': 68},
#               {'confidence': 73,
#                'latitude': -36.998,
#                'longitude': 148.1994,
#                'surface_temperature_celsius': 48},
#               {'confidence': 95,
#                'latitude': -36.9959,
#                'longitude': 148.2118,
#                'surface_temperature_celsius': 75},
#               {'confidence': 89,
#                'latitude': -34.3654,
#                'longitude': 141.543,
#                'surface_temperature_celsius': 65},
#               {'confidence': 73,
#                'latitude': -37.0228,
#                'longitude': 148.1996,
#                'surface_temperature_celsius': 52},
#               {'confidence': 81,
#                'latitude': -34.3539,
#                'longitude': 141.5629,
#                'surface_temperature_celsius': 55},
#               {'confidence': 96,
#                'latitude': -34.3554,
#                'longitude': 141.5413,
#                'surface_temperature_celsius': 79},
#               {'confidence': 94,
#                'latitude': -34.3555,
#                'longitude': 141.5495,
#                'surface_temperature_celsius': 75}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea172b'),
#  'hotspots': [{'confidence': 76,
#                'latitude': -34.3383,
#                'longitude': 141.543,
#                'surface_temperature_celsius': 56},
#               {'confidence': 94,
#                'latitude': -36.7152,
#                'longitude': 141.3853,
#                'surface_temperature_celsius': 74},
#               {'confidence': 78,
#                'latitude': -34.328,
#                'longitude': 141.5402,
#                'surface_temperature_celsius': 58},
#               {'confidence': 84,
#                'latitude': -36.6867,
#                'longitude': 141.137,
#                'surface_temperature_celsius': 59},
#               {'confidence': 76,
#                'latitude': -36.6889,
#                'longitude': 141.1239,
#                'surface_temperature_celsius': 50},
#               {'confidence': 86,
#                'latitude': -36.7128,
#                'longitude': 141.3986,
#                'surface_temperature_celsius': 60}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea172c'),
#  'hotspots': [{'confidence': 64,
#                'latitude': -37.4313,
#                'longitude': 147.0343,
#                'surface_temperature_celsius': 37},
#               {'confidence': 100,
#                'latitude': -37.017,
#                'longitude': 148.1297,
#                'surface_temperature_celsius': 121},
#               {'confidence': 97,
#                'latitude': -37.0155,
#                'longitude': 148.1432,
#                'surface_temperature_celsius': 80}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea172d'),
#  'hotspots': [{'confidence': 85,
#                'latitude': -37.6605,
#                'longitude': 142.1116,
#                'surface_temperature_celsius': 60},
#               {'confidence': 58,
#                'latitude': -37.9164,
#                'longitude': 143.4866,
#                'surface_temperature_celsius': 54},
#               {'confidence': 96,
#                'latitude': -37.6622,
#                'longitude': 142.1001,
#                'surface_temperature_celsius': 79},
#               {'confidence': 63,
#                'latitude': -37.9257,
#                'longitude': 143.4891,
#                'surface_temperature_celsius': 54},
#               {'confidence': 64,
#                'latitude': -37.3982,
#                'longitude': 147.0001,
#                'surface_temperature_celsius': 58},
#               {'confidence': 90,
#                'latitude': -37.4523,
#                'longitude': 147.0175,
#                'surface_temperature_celsius': 66},
#               {'confidence': 59,
#                'latitude': -37.4023,
#                'longitude': 147.0394,
#                'surface_temperature_celsius': 56},
#               {'confidence': 60,
#                'latitude': -37.4336,
#                'longitude': 147.0534,
#                'surface_temperature_celsius': 51},
#               {'confidence': 61,
#                'latitude': -37.4003,
#                'longitude': 147.0448,
#                'surface_temperature_celsius': 55},
#               {'confidence': 53,
#                'latitude': -37.9184,
#                'longitude': 143.4745,
#                'surface_temperature_celsius': 55},
#               {'confidence': 61,
#                'latitude': -37.3911,
#                'longitude': 147.037,
#                'surface_temperature_celsius': 50},
#               {'confidence': 98,
#                'latitude': -37.4261,
#                'longitude': 147.0323,
#                'surface_temperature_celsius': 83},
#               {'confidence': 100,
#                'latitude': -37.3949,
#                'longitude': 147.0175,
#                'surface_temperature_celsius': 91},
#               {'confidence': 84,
#                'latitude': -37.671,
#                'longitude': 144.6536,
#                'surface_temperature_celsius': 58},
#               {'confidence': 66,
#                'latitude': -37.9277,
#                'longitude': 143.477,
#                'surface_temperature_celsius': 55},
#               {'confidence': 100,
#                'latitude': -37.4224,
#                'longitude': 147.0511,
#                'surface_temperature_celsius': 113},
#               {'confidence': 92,
#                'latitude': -37.6625,
#                'longitude': 144.287,
#                'surface_temperature_celsius': 70},
#               {'confidence': 100,
#                'latitude': -37.4375,
#                'longitude': 147.0336,
#                'surface_temperature_celsius': 106},
#               {'confidence': 73,
#                'latitude': -37.4414,
#                'longitude': 147.0139,
#                'surface_temperature_celsius': 60},
#               {'confidence': 77,
#                'latitude': -37.4295,
#                'longitude': 147.0428,
#                'surface_temperature_celsius': 59},
#               {'confidence': 60,
#                'latitude': -37.3942,
#                'longitude': 147.0455,
#                'surface_temperature_celsius': 44}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1733'),
#  'hotspots': [{'confidence': 76,
#                'latitude': -37.8025,
#                'longitude': 145.8702,
#                'surface_temperature_celsius': 49},
#               {'confidence': 62,
#                'latitude': -37.8992,
#                'longitude': 143.4534,
#                'surface_temperature_celsius': 54},
#               {'confidence': 78,
#                'latitude': -37.8758,
#                'longitude': 145.8371,
#                'surface_temperature_celsius': 52},
#               {'confidence': 82,
#                'latitude': -37.8973,
#                'longitude': 143.4754,
#                'surface_temperature_celsius': 65},
#               {'confidence': 87,
#                'latitude': -37.7829,
#                'longitude': 143.5056,
#                'surface_temperature_celsius': 62},
#               {'confidence': 95,
#                'latitude': -37.7805,
#                'longitude': 143.5003,
#                'surface_temperature_celsius': 75},
#               {'confidence': 85,
#                'latitude': -37.5629,
#                'longitude': 144.752,
#                'surface_temperature_celsius': 59},
#               {'confidence': 100,
#                'latitude': -37.8122,
#                'longitude': 146.0807,
#                'surface_temperature_celsius': 111},
#               {'confidence': 95,
#                'latitude': -37.8774,
#                'longitude': 145.8213,
#                'surface_temperature_celsius': 77},
#               {'confidence': 75,
#                'latitude': -37.5742,
#                'longitude': 144.7536,
#                'surface_temperature_celsius': 49},
#               {'confidence': 100,
#                'latitude': -37.8881,
#                'longitude': 145.8229,
#                'surface_temperature_celsius': 99},
#               {'confidence': 73,
#                'latitude': -37.5612,
#                'longitude': 144.7701,
#                'surface_temperature_celsius': 49},
#               {'confidence': 57,
#                'latitude': -37.9022,
#                'longitude': 143.4607,
#                'surface_temperature_celsius': 57}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1734'),
#  'hotspots': [{'confidence': 74,
#                'latitude': -37.665,
#                'longitude': 142.1339,
#                'surface_temperature_celsius': 48},
#               {'confidence': 74,
#                'latitude': -38.0564,
#                'longitude': 142.8525,
#                'surface_temperature_celsius': 48},
#               {'confidence': 81,
#                'latitude': -38.018,
#                'longitude': 143.899,
#                'surface_temperature_celsius': 54},
#               {'confidence': 68,
#                'latitude': -38.1131,
#                'longitude': 143.7173,
#                'surface_temperature_celsius': 44},
#               {'confidence': 80,
#                'latitude': -38.1106,
#                'longitude': 143.7314,
#                'surface_temperature_celsius': 53},
#               {'confidence': 75,
#                'latitude': -37.8289,
#                'longitude': 145.9315,
#                'surface_temperature_celsius': 49},
#               {'confidence': 81,
#                'latitude': -38.0652,
#                'longitude': 142.9781,
#                'surface_temperature_celsius': 54},
#               {'confidence': 71,
#                'latitude': -37.522,
#                'longitude': 143.3874,
#                'surface_temperature_celsius': 73},
#               {'confidence': 91,
#                'latitude': -38.0674,
#                'longitude': 142.965,
#                'surface_temperature_celsius': 68},
#               {'confidence': 92,
#                'latitude': -38.0715,
#                'longitude': 142.9591,
#                'surface_temperature_celsius': 70},
#               {'confidence': 100,
#                'latitude': -38.0693,
#                'longitude': 142.9722,
#                'surface_temperature_celsius': 89},
#               {'confidence': 82,
#                'latitude': -37.9488,
#                'longitude': 143.8882,
#                'surface_temperature_celsius': 55},
#               {'confidence': 87,
#                'latitude': -37.9462,
#                'longitude': 143.9026,
#                'surface_temperature_celsius': 62},
#               {'confidence': 60,
#                'latitude': -37.8469,
#                'longitude': 143.5343,
#                'surface_temperature_celsius': 50},
#               {'confidence': 84,
#                'latitude': -37.8468,
#                'longitude': 142.8775,
#                'surface_temperature_celsius': 58},
#               {'confidence': 67,
#                'latitude': -37.1956,
#                'longitude': 141.0252,
#                'surface_temperature_celsius': 44},
#               {'confidence': 74,
#                'latitude': -38.0542,
#                'longitude': 142.8655,
#                'surface_temperature_celsius': 48}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1736'),
#  'hotspots': [{'confidence': 88,
#                'latitude': -36.4721,
#                'longitude': 142.2586,
#                'surface_temperature_celsius': 64},
#               {'confidence': 72,
#                'latitude': -36.7241,
#                'longitude': 141.0073,
#                'surface_temperature_celsius': 46},
#               {'confidence': 86,
#                'latitude': -38.004,
#                'longitude': 143.9249,
#                'surface_temperature_celsius': 60},
#               {'confidence': 92,
#                'latitude': -36.4557,
#                'longitude': 142.2434,
#                'surface_temperature_celsius': 71},
#               {'confidence': 95,
#                'latitude': -36.8009,
#                'longitude': 142.7259,
#                'surface_temperature_celsius': 76},
#               {'confidence': 74,
#                'latitude': -36.4737,
#                'longitude': 142.2474,
#                'surface_temperature_celsius': 55},
#               {'confidence': 93,
#                'latitude': -36.8099,
#                'longitude': 142.728,
#                'surface_temperature_celsius': 73},
#               {'confidence': 76,
#                'latitude': -36.8202,
#                'longitude': 141.9362,
#                'surface_temperature_celsius': 50},
#               {'confidence': 70,
#                'latitude': -36.9576,
#                'longitude': 141.5387,
#                'surface_temperature_celsius': 45},
#               {'confidence': 83,
#                'latitude': -36.811,
#                'longitude': 142.2655,
#                'surface_temperature_celsius': 56},
#               {'confidence': 80,
#                'latitude': -34.395,
#                'longitude': 142.0522,
#                'surface_temperature_celsius': 54},
#               {'confidence': 94,
#                'latitude': -36.7806,
#                'longitude': 141.5597,
#                'surface_temperature_celsius': 74},
#               {'confidence': 79,
#                'latitude': -37.639,
#                'longitude': 142.0648,
#                'surface_temperature_celsius': 52},
#               {'confidence': 72,
#                'latitude': -36.7791,
#                'longitude': 141.5711,
#                'surface_temperature_celsius': 46},
#               {'confidence': 98,
#                'latitude': -34.3526,
#                'longitude': 141.6458,
#                'surface_temperature_celsius': 82},
#               {'confidence': 81,
#                'latitude': -36.8189,
#                'longitude': 142.73,
#                'surface_temperature_celsius': 54},
#               {'confidence': 97,
#                'latitude': -37.0924,
#                'longitude': 141.897,
#                'surface_temperature_celsius': 80},
#               {'confidence': 77,
#                'latitude': -36.4827,
#                'longitude': 142.2494,
#                'surface_temperature_celsius': 51},
#               {'confidence': 53,
#                'latitude': -37.6195,
#                'longitude': 143.4212,
#                'surface_temperature_celsius': 46},
#               {'confidence': 81,
#                'latitude': -34.386,
#                'longitude': 142.0503,
#                'surface_temperature_celsius': 54},
#               {'confidence': 79,
#                'latitude': -36.8293,
#                'longitude': 141.9382,
#                'surface_temperature_celsius': 52},
#               {'confidence': 88,
#                'latitude': -36.4573,
#                'longitude': 142.2323,
#                'surface_temperature_celsius': 63},
#               {'confidence': 87,
#                'latitude': -37.4996,
#                'longitude': 142.5966,
#                'surface_temperature_celsius': 62},
#               {'confidence': 79,
#                'latitude': -34.4501,
#                'longitude': 141.4699,
#                'surface_temperature_celsius': 52},
#               {'confidence': 97,
#                'latitude': -37.9452,
#                'longitude': 143.5834,
#                'surface_temperature_celsius': 80},
#               {'confidence': 100,
#                'latitude': -37.9526,
#                'longitude': 143.597,
#                'surface_temperature_celsius': 107},
#               {'confidence': 77,
#                'latitude': -36.4811,
#                'longitude': 142.2606,
#                'surface_temperature_celsius': 50},
#               {'confidence': 76,
#                'latitude': -36.4483,
#                'longitude': 142.2303,
#                'surface_temperature_celsius': 49},
#               {'confidence': 100,
#                'latitude': -37.6269,
#                'longitude': 143.4348,
#                'surface_temperature_celsius': 108},
#               {'confidence': 82,
#                'latitude': -36.7131,
#                'longitude': 142.4338,
#                'surface_temperature_celsius': 55},
#               {'confidence': 99,
#                'latitude': -34.351,
#                'longitude': 141.6567,
#                'surface_temperature_celsius': 86},
#               {'confidence': 77,
#                'latitude': -35.0917,
#                'longitude': 141.1508,
#                'surface_temperature_celsius': 50},
#               {'confidence': 76,
#                'latitude': -36.6798,
#                'longitude': 141.1299,
#                'surface_temperature_celsius': 50},
#               {'confidence': 81,
#                'latitude': -36.8218,
#                'longitude': 141.9249,
#                'surface_temperature_celsius': 55},
#               {'confidence': 80,
#                'latitude': -36.82,
#                'longitude': 142.2675,
#                'surface_temperature_celsius': 53},
#               {'confidence': 83,
#                'latitude': -37.094,
#                'longitude': 141.8857,
#                'surface_temperature_celsius': 57},
#               {'confidence': 100,
#                'latitude': -37.5012,
#                'longitude': 142.5853,
#                'surface_temperature_celsius': 90},
#               {'confidence': 63,
#                'latitude': -37.6376,
#                'longitude': 143.4255,
#                'surface_temperature_celsius': 48},
#               {'confidence': 72,
#                'latitude': -37.8328,
#                'longitude': 142.5142,
#                'surface_temperature_celsius': 46},
#               {'confidence': 87,
#                'latitude': -37.8051,
#                'longitude': 143.0309,
#                'surface_temperature_celsius': 62},
#               {'confidence': 97,
#                'latitude': -37.9247,
#                'longitude': 142.8999,
#                'surface_temperature_celsius': 81},
#               {'confidence': 85,
#                'latitude': -37.9231,
#                'longitude': 142.9113,
#                'surface_temperature_celsius': 59},
#               {'confidence': 88,
#                'latitude': -37.9435,
#                'longitude': 143.5948,
#                'surface_temperature_celsius': 63},
#               {'confidence': 87,
#                'latitude': -38.0221,
#                'longitude': 143.9294,
#                'surface_temperature_celsius': 62},
#               {'confidence': 84,
#                'latitude': -37.1609,
#                'longitude': 149.0754,
#                'surface_temperature_celsius': 58},
#               {'confidence': 73,
#                'latitude': -36.4541,
#                'longitude': 142.2546,
#                'surface_temperature_celsius': 51},
#               {'confidence': 79,
#                'latitude': -36.4513,
#                'longitude': 141.4191,
#                'surface_temperature_celsius': 52},
#               {'confidence': 69,
#                'latitude': -36.4422,
#                'longitude': 141.4172,
#                'surface_temperature_celsius': 46},
#               {'confidence': 97,
#                'latitude': -35.0805,
#                'longitude': 142.4642,
#                'surface_temperature_celsius': 81},
#               {'confidence': 78,
#                'latitude': -36.7257,
#                'longitude': 140.9956,
#                'surface_temperature_celsius': 51},
#               {'confidence': 83,
#                'latitude': -35.0821,
#                'longitude': 142.4532,
#                'surface_temperature_celsius': 57},
#               {'confidence': 78,
#                'latitude': -36.6783,
#                'longitude': 141.1415,
#                'surface_temperature_celsius': 51},
#               {'confidence': 85,
#                'latitude': -34.3616,
#                'longitude': 141.6477,
#                'surface_temperature_celsius': 60},
#               {'confidence': 55,
#                'latitude': -34.342,
#                'longitude': 141.6548,
#                'surface_temperature_celsius': 54}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea173c'),
#  'hotspots': [{'confidence': 72,
#                'latitude': -36.1141,
#                'longitude': 141.6787,
#                'surface_temperature_celsius': 37},
#               {'confidence': 91,
#                'latitude': -37.8046,
#                'longitude': 146.0304,
#                'surface_temperature_celsius': 43},
#               {'confidence': 83,
#                'latitude': -37.9068,
#                'longitude': 145.9047,
#                'surface_temperature_celsius': 40},
#               {'confidence': 100,
#                'latitude': -36.1156,
#                'longitude': 141.6664,
#                'surface_temperature_celsius': 62},
#               {'confidence': 96,
#                'latitude': -37.8064,
#                'longitude': 146.0189,
#                'surface_temperature_celsius': 45},
#               {'confidence': 76,
#                'latitude': -37.0221,
#                'longitude': 141.5517,
#                'surface_temperature_celsius': 50},
#               {'confidence': 87,
#                'latitude': -37.3735,
#                'longitude': 145.886,
#                'surface_temperature_celsius': 96},
#               {'confidence': 75,
#                'latitude': -37.5422,
#                'longitude': 143.2276,
#                'surface_temperature_celsius': 49},
#               {'confidence': 93,
#                'latitude': -37.7465,
#                'longitude': 143.3806,
#                'surface_temperature_celsius': 72},
#               {'confidence': 77,
#                'latitude': -37.3094,
#                'longitude': 146.1945,
#                'surface_temperature_celsius': 60},
#               {'confidence': 82,
#                'latitude': -36.7199,
#                'longitude': 141.3946,
#                'surface_temperature_celsius': 55},
#               {'confidence': 79,
#                'latitude': -35.7638,
#                'longitude': 142.1215,
#                'surface_temperature_celsius': 52},
#               {'confidence': 88,
#                'latitude': -36.1534,
#                'longitude': 141.5948,
#                'surface_temperature_celsius': 64},
#               {'confidence': 95,
#                'latitude': -37.8072,
#                'longitude': 145.9738,
#                'surface_temperature_celsius': 77},
#               {'confidence': 96,
#                'latitude': -37.3704,
#                'longitude': 145.8942,
#                'surface_temperature_celsius': 78},
#               {'confidence': 100,
#                'latitude': -37.297,
#                'longitude': 143.5753,
#                'surface_temperature_celsius': 93},
#               {'confidence': 71,
#                'latitude': -36.9172,
#                'longitude': 142.0472,
#                'surface_temperature_celsius': 45},
#               {'confidence': 69,
#                'latitude': -37.8668,
#                'longitude': 143.0472,
#                'surface_temperature_celsius': 44},
#               {'confidence': 68,
#                'latitude': -37.7602,
#                'longitude': 143.382,
#                'surface_temperature_celsius': 44},
#               {'confidence': 85,
#                'latitude': -37.7529,
#                'longitude': 143.3745,
#                'surface_temperature_celsius': 59},
#               {'confidence': 66,
#                'latitude': -37.7885,
#                'longitude': 142.9509,
#                'surface_temperature_celsius': 43},
#               {'confidence': 74,
#                'latitude': -34.2714,
#                'longitude': 141.6197,
#                'surface_temperature_celsius': 48},
#               {'confidence': 84,
#                'latitude': -36.1698,
#                'longitude': 142.0536,
#                'surface_temperature_celsius': 58},
#               {'confidence': 100,
#                'latitude': -37.2988,
#                'longitude': 143.5487,
#                'surface_temperature_celsius': 90},
#               {'confidence': 100,
#                'latitude': -37.3716,
#                'longitude': 145.9065,
#                'surface_temperature_celsius': 115},
#               {'confidence': 71,
#                'latitude': -37.8662,
#                'longitude': 143.251,
#                'surface_temperature_celsius': 46},
#               {'confidence': 86,
#                'latitude': -36.4291,
#                'longitude': 141.2426,
#                'surface_temperature_celsius': 61},
#               {'confidence': 76,
#                'latitude': -37.2891,
#                'longitude': 143.5697,
#                'surface_temperature_celsius': 50},
#               {'confidence': 100,
#                'latitude': -37.3025,
#                'longitude': 143.5714,
#                'surface_temperature_celsius': 98},
#               {'confidence': 100,
#                'latitude': -37.383,
#                'longitude': 145.9089,
#                'surface_temperature_celsius': 89},
#               {'confidence': 85,
#                'latitude': -37.7216,
#                'longitude': 143.4272,
#                'surface_temperature_celsius': 59},
#               {'confidence': 75,
#                'latitude': -37.8717,
#                'longitude': 143.3652,
#                'surface_temperature_celsius': 49},
#               {'confidence': 66,
#                'latitude': -37.8717,
#                'longitude': 143.2566,
#                'surface_temperature_celsius': 43},
#               {'confidence': 83,
#                'latitude': -37.3851,
#                'longitude': 145.8878,
#                'surface_temperature_celsius': 63},
#               {'confidence': 89,
#                'latitude': -37.7446,
#                'longitude': 143.4085,
#                'surface_temperature_celsius': 66},
#               {'confidence': 75,
#                'latitude': -36.7159,
#                'longitude': 141.3991,
#                'surface_temperature_celsius': 49},
#               {'confidence': 87,
#                'latitude': -35.7626,
#                'longitude': 142.1167,
#                'surface_temperature_celsius': 62},
#               {'confidence': 67,
#                'latitude': -37.8011,
#                'longitude': 144.7343,
#                'surface_temperature_celsius': 44},
#               {'confidence': 81,
#                'latitude': -37.8777,
#                'longitude': 143.371,
#                'surface_temperature_celsius': 54},
#               {'confidence': 98,
#                'latitude': -37.7509,
#                'longitude': 143.4023,
#                'surface_temperature_celsius': 82},
#               {'confidence': 80,
#                'latitude': -36.6085,
#                'longitude': 142.4451,
#                'surface_temperature_celsius': 53},
#               {'confidence': 100,
#                'latitude': -37.3802,
#                'longitude': 145.9147,
#                'surface_temperature_celsius': 103},
#               {'confidence': 87,
#                'latitude': -37.7974,
#                'longitude': 145.9535,
#                'surface_temperature_celsius': 97},
#               {'confidence': 67,
#                'latitude': -37.0241,
#                'longitude': 141.5163,
#                'surface_temperature_celsius': 43},
#               {'confidence': 66,
#                'latitude': -37.2912,
#                'longitude': 143.543,
#                'surface_temperature_celsius': 43},
#               {'confidence': 52,
#                'latitude': -37.313,
#                'longitude': 146.1561,
#                'surface_temperature_celsius': 46},
#               {'confidence': 56,
#                'latitude': -38.0226,
#                'longitude': 143.6739,
#                'surface_temperature_celsius': 39},
#               {'confidence': 90,
#                'latitude': -35.7657,
#                'longitude': 142.0906,
#                'surface_temperature_celsius': 66},
#               {'confidence': 73,
#                'latitude': -37.9029,
#                'longitude': 143.5946,
#                'surface_temperature_celsius': 47},
#               {'confidence': 77,
#                'latitude': -36.9151,
#                'longitude': 142.0798,
#                'surface_temperature_celsius': 50},
#               {'confidence': 85,
#                'latitude': -37.9112,
#                'longitude': 143.6025,
#                'surface_temperature_celsius': 61},
#               {'confidence': 56,
#                'latitude': -37.8089,
#                'longitude': 145.9555,
#                'surface_temperature_celsius': 41},
#               {'confidence': 62,
#                'latitude': -37.9009,
#                'longitude': 143.6217,
#                'surface_temperature_celsius': 45},
#               {'confidence': 70,
#                'latitude': -37.7583,
#                'longitude': 143.41,
#                'surface_temperature_celsius': 45},
#               {'confidence': 69,
#                'latitude': -37.7836,
#                'longitude': 142.9437,
#                'surface_temperature_celsius': 44},
#               {'confidence': 99,
#                'latitude': -37.7236,
#                'longitude': 143.3995,
#                'surface_temperature_celsius': 86},
#               {'confidence': 76,
#                'latitude': -37.5402,
#                'longitude': 143.2559,
#                'surface_temperature_celsius': 50},
#               {'confidence': 93,
#                'latitude': -37.3046,
#                'longitude': 143.5448,
#                'surface_temperature_celsius': 72},
#               {'confidence': 52,
#                'latitude': -37.0484,
#                'longitude': 141.6245,
#                'surface_temperature_celsius': 42},
#               {'confidence': 68,
#                'latitude': -36.911,
#                'longitude': 142.1445,
#                'surface_temperature_celsius': 47},
#               {'confidence': 95,
#                'latitude': -36.4312,
#                'longitude': 141.2064,
#                'surface_temperature_celsius': 76},
#               {'confidence': 86,
#                'latitude': -36.1702,
#                'longitude': 142.0586,
#                'surface_temperature_celsius': 60},
#               {'confidence': 73,
#                'latitude': -36.1722,
#                'longitude': 142.0266,
#                'surface_temperature_celsius': 47},
#               {'confidence': 89,
#                'latitude': -36.1556,
#                'longitude': 141.5904,
#                'surface_temperature_celsius': 65},
#               {'confidence': 72,
#                'latitude': -35.7598,
#                'longitude': 143.851,
#                'surface_temperature_celsius': 46},
#               {'confidence': 82,
#                'latitude': -35.7609,
#                'longitude': 143.8442,
#                'surface_temperature_celsius': 55},
#               {'confidence': 89,
#                'latitude': -35.7647,
#                'longitude': 142.0858,
#                'surface_temperature_celsius': 65},
#               {'confidence': 67,
#                'latitude': -34.2536,
#                'longitude': 141.6199,
#                'surface_temperature_celsius': 46},
#               {'confidence': 77,
#                'latitude': -34.2674,
#                'longitude': 141.6183,
#                'surface_temperature_celsius': 51},
#               {'confidence': 71,
#                'latitude': -36.7885,
#                'longitude': 142.1258,
#                'surface_temperature_celsius': 46},
#               {'confidence': 81,
#                'latitude': -34.2594,
#                'longitude': 141.6139,
#                'surface_temperature_celsius': 54},
#               {'confidence': 57,
#                'latitude': -34.2614,
#                'longitude': 141.6412,
#                'surface_temperature_celsius': 43}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea173d'),
#  'hotspots': [{'confidence': 76,
#                'latitude': -37.2162,
#                'longitude': 146.2408,
#                'surface_temperature_celsius': 38},
#               {'confidence': 93,
#                'latitude': -36.087,
#                'longitude': 141.7227,
#                'surface_temperature_celsius': 44},
#               {'confidence': 63,
#                'latitude': -36.0933,
#                'longitude': 141.7154,
#                'surface_temperature_celsius': 35},
#               {'confidence': 100,
#                'latitude': -36.0852,
#                'longitude': 141.7112,
#                'surface_temperature_celsius': 64},
#               {'confidence': 88,
#                'latitude': -36.3194,
#                'longitude': 141.7531,
#                'surface_temperature_celsius': 63},
#               {'confidence': 82,
#                'latitude': -37.3601,
#                'longitude': 145.8519,
#                'surface_temperature_celsius': 62},
#               {'confidence': 88,
#                'latitude': -36.1598,
#                'longitude': 141.8841,
#                'surface_temperature_celsius': 64},
#               {'confidence': 86,
#                'latitude': -36.6936,
#                'longitude': 145.2788,
#                'surface_temperature_celsius': 61},
#               {'confidence': 100,
#                'latitude': -36.1057,
#                'longitude': 141.7608,
#                'surface_temperature_celsius': 120},
#               {'confidence': 90,
#                'latitude': -35.4033,
#                'longitude': 143.267,
#                'surface_temperature_celsius': 67},
#               {'confidence': 64,
#                'latitude': -36.6281,
#                'longitude': 142.4349,
#                'surface_temperature_celsius': 68},
#               {'confidence': 85,
#                'latitude': -36.111,
#                'longitude': 145.124,
#                'surface_temperature_celsius': 66},
#               {'confidence': 90,
#                'latitude': -36.1615,
#                'longitude': 141.8728,
#                'surface_temperature_celsius': 66},
#               {'confidence': 81,
#                'latitude': -37.3074,
#                'longitude': 142.9925,
#                'surface_temperature_celsius': 54},
#               {'confidence': 61,
#                'latitude': -36.937,
#                'longitude': 142.1176,
#                'surface_temperature_celsius': 50},
#               {'confidence': 70,
#                'latitude': -38.1868,
#                'longitude': 143.0938,
#                'surface_temperature_celsius': 45},
#               {'confidence': 77,
#                'latitude': -35.2601,
#                'longitude': 143.1931,
#                'surface_temperature_celsius': 50},
#               {'confidence': 100,
#                'latitude': -36.1849,
#                'longitude': 145.9109,
#                'surface_temperature_celsius': 107},
#               {'confidence': 74,
#                'latitude': -37.2109,
#                'longitude': 142.7966,
#                'surface_temperature_celsius': 52},
#               {'confidence': 50,
#                'latitude': -36.6951,
#                'longitude': 145.424,
#                'surface_temperature_celsius': 43},
#               {'confidence': 76,
#                'latitude': -36.1376,
#                'longitude': 145.84,
#                'surface_temperature_celsius': 55},
#               {'confidence': 88,
#                'latitude': -36.6965,
#                'longitude': 142.7116,
#                'surface_temperature_celsius': 64},
#               {'confidence': 79,
#                'latitude': -37.0753,
#                'longitude': 141.0532,
#                'surface_temperature_celsius': 52},
#               {'confidence': 67,
#                'latitude': -37.6714,
#                'longitude': 144.2154,
#                'surface_temperature_celsius': 46},
#               {'confidence': 70,
#                'latitude': -37.4465,
#                'longitude': 143.5163,
#                'surface_temperature_celsius': 50},
#               {'confidence': 63,
#                'latitude': -38.0494,
#                'longitude': 143.9141,
#                'surface_temperature_celsius': 58},
#               {'confidence': 72,
#                'latitude': -38.1356,
#                'longitude': 143.7098,
#                'surface_temperature_celsius': 50},
#               {'confidence': 75,
#                'latitude': -37.3632,
#                'longitude': 145.8356,
#                'surface_temperature_celsius': 53},
#               {'confidence': 88,
#                'latitude': -36.6078,
#                'longitude': 141.9742,
#                'surface_temperature_celsius': 63},
#               {'confidence': 87,
#                'latitude': -37.3765,
#                'longitude': 145.8221,
#                'surface_temperature_celsius': 62},
#               {'confidence': 72,
#                'latitude': -36.0694,
#                'longitude': 141.5717,
#                'surface_temperature_celsius': 54},
#               {'confidence': 90,
#                'latitude': -36.1122,
#                'longitude': 142.1491,
#                'surface_temperature_celsius': 76},
#               {'confidence': 77,
#                'latitude': -36.401,
#                'longitude': 145.5113,
#                'surface_temperature_celsius': 55},
#               {'confidence': 76,
#                'latitude': -37.9048,
#                'longitude': 145.7738,
#                'surface_temperature_celsius': 49},
#               {'confidence': 100,
#                'latitude': -37.3735,
#                'longitude': 145.8384,
#                'surface_temperature_celsius': 95},
#               {'confidence': 83,
#                'latitude': -35.4128,
#                'longitude': 143.2693,
#                'surface_temperature_celsius': 57},
#               {'confidence': 70,
#                'latitude': -36.8848,
#                'longitude': 142.1523,
#                'surface_temperature_celsius': 51},
#               {'confidence': 89,
#                'latitude': -35.4255,
#                'longitude': 143.6306,
#                'surface_temperature_celsius': 65},
#               {'confidence': 79,
#                'latitude': -36.1198,
#                'longitude': 145.6369,
#                'surface_temperature_celsius': 52},
#               {'confidence': 54,
#                'latitude': -38.4879,
#                'longitude': 143.9971,
#                'surface_temperature_celsius': 40},
#               {'confidence': 96,
#                'latitude': -36.1955,
#                'longitude': 145.914,
#                'surface_temperature_celsius': 78},
#               {'confidence': 85,
#                'latitude': -35.4533,
#                'longitude': 143.2029,
#                'surface_temperature_celsius': 66},
#               {'confidence': 84,
#                'latitude': -35.4993,
#                'longitude': 143.3105,
#                'surface_temperature_celsius': 57},
#               {'confidence': 92,
#                'latitude': -36.5989,
#                'longitude': 141.9771,
#                'surface_temperature_celsius': 81},
#               {'confidence': 81,
#                'latitude': -37.4485,
#                'longitude': 143.5041,
#                'surface_temperature_celsius': 54},
#               {'confidence': 63,
#                'latitude': -37.1744,
#                'longitude': 143.9256,
#                'surface_temperature_celsius': 43},
#               {'confidence': 100,
#                'latitude': -36.104,
#                'longitude': 141.772,
#                'surface_temperature_celsius': 113},
#               {'confidence': 69,
#                'latitude': -36.4918,
#                'longitude': 142.2465,
#                'surface_temperature_celsius': 54},
#               {'confidence': 80,
#                'latitude': -36.6663,
#                'longitude': 143.2603,
#                'surface_temperature_celsius': 58},
#               {'confidence': 75,
#                'latitude': -36.0189,
#                'longitude': 145.6844,
#                'surface_temperature_celsius': 49},
#               {'confidence': 85,
#                'latitude': -35.7523,
#                'longitude': 143.8866,
#                'surface_temperature_celsius': 59},
#               {'confidence': 72,
#                'latitude': -36.6538,
#                'longitude': 142.7552,
#                'surface_temperature_celsius': 53},
#               {'confidence': 66,
#                'latitude': -36.6299,
#                'longitude': 142.4234,
#                'surface_temperature_celsius': 71},
#               {'confidence': 82,
#                'latitude': -36.0994,
#                'longitude': 143.4156,
#                'surface_temperature_celsius': 62},
#               {'confidence': 82,
#                'latitude': -36.8395,
#                'longitude': 142.2188,
#                'surface_temperature_celsius': 62},
#               {'confidence': 78,
#                'latitude': -36.9294,
#                'longitude': 142.7087,
#                'surface_temperature_celsius': 51},
#               {'confidence': 53,
#                'latitude': -36.1439,
#                'longitude': 145.832,
#                'surface_temperature_celsius': 50},
#               {'confidence': 97,
#                'latitude': -36.1925,
#                'longitude': 145.93,
#                'surface_temperature_celsius': 79},
#               {'confidence': 86,
#                'latitude': -37.8351,
#                'longitude': 145.9789,
#                'surface_temperature_celsius': 61},
#               {'confidence': 98,
#                'latitude': -36.095,
#                'longitude': 141.7699,
#                'surface_temperature_celsius': 82},
#               {'confidence': 85,
#                'latitude': -36.7848,
#                'longitude': 141.9044,
#                'surface_temperature_celsius': 61},
#               {'confidence': 84,
#                'latitude': -36.6962,
#                'longitude': 145.2642,
#                'surface_temperature_celsius': 58},
#               {'confidence': 82,
#                'latitude': -37.1089,
#                'longitude': 143.0783,
#                'surface_temperature_celsius': 55},
#               {'confidence': 54,
#                'latitude': -36.7009,
#                'longitude': 141.541,
#                'surface_temperature_celsius': 49},
#               {'confidence': 70,
#                'latitude': -36.4604,
#                'longitude': 142.1623,
#                'surface_temperature_celsius': 48},
#               {'confidence': 100,
#                'latitude': -36.343,
#                'longitude': 142.1986,
#                'surface_temperature_celsius': 123},
#               {'confidence': 82,
#                'latitude': -36.2906,
#                'longitude': 141.758,
#                'surface_temperature_celsius': 55},
#               {'confidence': 100,
#                'latitude': -36.114,
#                'longitude': 142.1377,
#                'surface_temperature_celsius': 118},
#               {'confidence': 80,
#                'latitude': -37.5436,
#                'longitude': 143.6122,
#                'surface_temperature_celsius': 54},
#               {'confidence': 96,
#                'latitude': -36.6006,
#                'longitude': 141.9657,
#                'surface_temperature_celsius': 78},
#               {'confidence': 55,
#                'latitude': -36.4611,
#                'longitude': 143.146,
#                'surface_temperature_celsius': 48},
#               {'confidence': 93,
#                'latitude': -37.0769,
#                'longitude': 141.042,
#                'surface_temperature_celsius': 72},
#               {'confidence': 100,
#                'latitude': -36.3521,
#                'longitude': 142.2008,
#                'surface_temperature_celsius': 120},
#               {'confidence': 53,
#                'latitude': -36.3539,
#                'longitude': 142.1894,
#                'surface_temperature_celsius': 53},
#               {'confidence': 79,
#                'latitude': -36.883,
#                'longitude': 142.1637,
#                'surface_temperature_celsius': 67},
#               {'confidence': 87,
#                'latitude': -36.0973,
#                'longitude': 143.4279,
#                'surface_temperature_celsius': 92},
#               {'confidence': 79,
#                'latitude': -36.7722,
#                'longitude': 141.5514,
#                'surface_temperature_celsius': 58},
#               {'confidence': 66,
#                'latitude': -37.0081,
#                'longitude': 141.7654,
#                'surface_temperature_celsius': 62},
#               {'confidence': 100,
#                'latitude': -36.0967,
#                'longitude': 141.7587,
#                'surface_temperature_celsius': 101},
#               {'confidence': 73,
#                'latitude': -36.4204,
#                'longitude': 141.3765,
#                'surface_temperature_celsius': 57},
#               {'confidence': 64,
#                'latitude': -36.2889,
#                'longitude': 141.7692,
#                'surface_temperature_celsius': 51},
#               {'confidence': 74,
#                'latitude': -35.4439,
#                'longitude': 143.2005,
#                'surface_temperature_celsius': 54},
#               {'confidence': 67,
#                'latitude': -36.6228,
#                'longitude': 142.428,
#                'surface_temperature_celsius': 43},
#               {'confidence': 81,
#                'latitude': -36.2205,
#                'longitude': 141.7933,
#                'surface_temperature_celsius': 54},
#               {'confidence': 60,
#                'latitude': -38.1177,
#                'longitude': 143.6409,
#                'surface_temperature_celsius': 40},
#               {'confidence': 100,
#                'latitude': -36.1819,
#                'longitude': 145.9269,
#                'surface_temperature_celsius': 98},
#               {'confidence': 72,
#                'latitude': -35.4594,
#                'longitude': 143.7125,
#                'surface_temperature_celsius': 46},
#               {'confidence': 79,
#                'latitude': -34.2708,
#                'longitude': 141.6158,
#                'surface_temperature_celsius': 52},
#               {'confidence': 80,
#                'latitude': -35.4616,
#                'longitude': 143.7251,
#                'surface_temperature_celsius': 53}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea173e'),
#  'hotspots': [{'confidence': 61,
#                'latitude': -38.3499,
# ...
#                'surface_temperature_celsius': 51},
#               {'confidence': 91,
#                'latitude': -37.247,
#                'longitude': 141.278,
#                'surface_temperature_celsius': 68},
#               {'confidence': 58,
#                'latitude': -37.587,
#                'longitude': 142.479,
#                'surface_temperature_celsius': 41},
#               {'confidence': 82,
#                'latitude': -37.805,
#                'longitude': 144.15,
#                'surface_temperature_celsius': 55}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1805'),
#  'hotspots': [{'confidence': 77,
#                'latitude': -36.1,
#                'longitude': 143.767,
#                'surface_temperature_celsius': 44},
#               {'confidence': 88,
#                'latitude': -36.098,
#                'longitude': 143.735,
#                'surface_temperature_celsius': 59},
#               {'confidence': 65,
#                'latitude': -36.1,
#                'longitude': 143.772,
#                'surface_temperature_celsius': 35},
#               {'confidence': 92,
#                'latitude': -36.098,
#                'longitude': 143.74,
#                'surface_temperature_celsius': 67}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1814'),
#  'hotspots': [{'confidence': 83,
#                'latitude': -36.341,
#                'longitude': 143.636,
#                'surface_temperature_celsius': 58},
#               {'confidence': 71,
#                'latitude': -36.346,
#                'longitude': 143.631,
#                'surface_temperature_celsius': 49},
#               {'confidence': 90,
#                'latitude': -37.331,
#                'longitude': 143.122,
#                'surface_temperature_celsius': 65},
#               {'confidence': 89,
#                'latitude': -37.329,
#                'longitude': 143.136,
#                'surface_temperature_celsius': 62}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1818'),
#  'hotspots': [{'confidence': 68,
#                'latitude': -36.759,
#                'longitude': 145.179,
#                'surface_temperature_celsius': 52},
#               {'confidence': 62,
#                'latitude': -36.758,
#                'longitude': 145.19,
#                'surface_temperature_celsius': 51},
#               {'confidence': 75,
#                'latitude': -37.213,
#                'longitude': 142.941,
#                'surface_temperature_celsius': 51},
#               {'confidence': 85,
#                'latitude': -37.479,
#                'longitude': 143.358,
#                'surface_temperature_celsius': 59},
#               {'confidence': 72,
#                'latitude': -37.467,
#                'longitude': 143.351,
#                'surface_temperature_celsius': 47},
#               {'confidence': 100,
#                'latitude': -37.477,
#                'longitude': 143.352,
#                'surface_temperature_celsius': 93},
#               {'confidence': 96,
#                'latitude': -37.475,
#                'longitude': 143.365,
#                'surface_temperature_celsius': 77},
#               {'confidence': 63,
#                'latitude': -37.719,
#                'longitude': 142.154,
#                'surface_temperature_celsius': 41},
#               {'confidence': 87,
#                'latitude': -37.692,
#                'longitude': 143.593,
#                'surface_temperature_celsius': 62},
#               {'confidence': 97,
#                'latitude': -37.69,
#                'longitude': 143.605,
#                'surface_temperature_celsius': 80}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea181b'),
#  'hotspots': [{'confidence': 63,
#                'latitude': -36.942,
#                'longitude': 143.282,
#                'surface_temperature_celsius': 53},
#               {'confidence': 58,
#                'latitude': -37.864,
#                'longitude': 144.174,
#                'surface_temperature_celsius': 41},
#               {'confidence': 56,
#                'latitude': -38.912,
#                'longitude': 146.272,
#                'surface_temperature_celsius': 48},
#               {'confidence': 67,
#                'latitude': -36.942,
#                'longitude': 143.292,
#                'surface_temperature_celsius': 54},
#               {'confidence': 89,
#                'latitude': -36.94,
#                'longitude': 143.281,
#                'surface_temperature_celsius': 69}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea181d'),
#  'hotspots': [{'confidence': 87,
#                'latitude': -37.862,
#                'longitude': 144.175,
#                'surface_temperature_celsius': 65},
#               {'confidence': 64,
#                'latitude': -38.527,
#                'longitude': 143.493,
#                'surface_temperature_celsius': 45},
#               {'confidence': 64,
#                'latitude': -37.332,
#                'longitude': 143.375,
#                'surface_temperature_celsius': 46}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1826'),
#  'hotspots': [{'confidence': 84,
#                'latitude': -37.946,
#                'longitude': 144.342,
#                'surface_temperature_celsius': 60},
#               {'confidence': 93,
#                'latitude': -37.945,
#                'longitude': 144.354,
#                'surface_temperature_celsius': 73},
#               {'confidence': 68,
#                'latitude': -38.141,
#                'longitude': 143.183,
#                'surface_temperature_celsius': 46},
#               {'confidence': 63,
#                'latitude': -36.952,
#                'longitude': 144.972,
#                'surface_temperature_celsius': 60},
#               {'confidence': 70,
#                'latitude': -34.965,
#                'longitude': 142.031,
#                'surface_temperature_celsius': 55}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea182c'),
#  'hotspots': [{'confidence': 53,
#                'latitude': -37.611,
#                'longitude': 149.277,
#                'surface_temperature_celsius': 38},
#               {'confidence': 100,
#                'latitude': -37.608,
#                'longitude': 149.292,
#                'surface_temperature_celsius': 55},
#               {'confidence': 68,
#                'latitude': -37.605,
#                'longitude': 149.308,
#                'surface_temperature_celsius': 43},
#               {'confidence': 52,
#                'latitude': -34.282,
#                'longitude': 142.121,
#                'surface_temperature_celsius': 54},
#               {'confidence': 100,
#                'latitude': -37.606,
#                'longitude': 149.312,
#                'surface_temperature_celsius': 87},
#               {'confidence': 64,
#                'latitude': -37.605,
#                'longitude': 149.326,
#                'surface_temperature_celsius': 44},
#               {'confidence': 97,
#                'latitude': -37.61,
#                'longitude': 149.307,
#                'surface_temperature_celsius': 80},
#               {'confidence': 99,
#                'latitude': -37.609,
#                'longitude': 149.32,
#                'surface_temperature_celsius': 84}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea182d'),
#  'hotspots': [{'confidence': 52,
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celsius': 47},
#               {'confidence': 100,
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celsius': 53},
#               {'confidence': 51,
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celsius': 42},
#               {'confidence': 64,
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celsius': 42},
#               {'confidence': 100,
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celsius': 54},
#               {'confidence': 69,
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celsius': 35},
#               {'confidence': 100,
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celsius': 49},
#               {'confidence': 61,
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celsius': 31},
#               {'confidence': 62,
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celsius': 33},
#               {'confidence': 64,
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celsius': 32},
#               {'confidence': 84,
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celsius': 38},
#               {'confidence': 81,
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celsius': 42},
#               {'confidence': 100,
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celsius': 55},
#               {'confidence': 100,
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celsius': 65},
#               {'confidence': 100,
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celsius': 71},
#               {'confidence': 84,
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celsius': 59},
#               {'confidence': 73,
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celsius': 50},
#               {'confidence': 98,
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celsius': 83},
#               {'confidence': 81,
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celsius': 57},
#               {'confidence': 84,
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celsius': 61},
#               {'confidence': 99,
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celsius': 86},
#               {'confidence': 69,
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celsius': 48},
#               {'confidence': 60,
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celsius': 42},
#               {'confidence': 83,
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celsius': 58},
#               {'confidence': 87,
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celsius': 63},
#               {'confidence': 95,
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celsius': 76},
#               {'confidence': 81,
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celsius': 56},
#               {'confidence': 73,
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celsius': 51},
#               {'confidence': 81,
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celsius': 55},
#               {'confidence': 69,
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celsius': 50},
#               {'confidence': 64,
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celsius': 41}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1835'),
#  'hotspots': [{'confidence': 77,
#                'latitude': -36.273,
#                'longitude': 146.155,
#                'surface_temperature_celsius': 36},
#               {'confidence': 100,
#                'latitude': -36.284,
#                'longitude': 146.145,
#                'surface_temperature_celsius': 54},
#               {'confidence': 100,
#                'latitude': -36.282,
#                'longitude': 146.157,
#                'surface_temperature_celsius': 71},
#               {'confidence': 100,
#                'latitude': -36.293,
#                'longitude': 146.148,
#                'surface_temperature_celsius': 52},
#               {'confidence': 56,
#                'latitude': -36.291,
#                'longitude': 146.159,
#                'surface_temperature_celsius': 40}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea183b'),
#  'hotspots': [{'confidence': 92,
#                'latitude': -37.95,
#                'longitude': 142.366,
#                'surface_temperature_celsius': 70}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea183d'),
#  'hotspots': [{'confidence': 94,
#                'latitude': -37.636,
#                'longitude': 149.33,
#                'surface_temperature_celsius': 43},
#               {'confidence': 69,
#                'latitude': -37.624,
#                'longitude': 149.332,
#                'surface_temperature_celsius': 33},
#               {'confidence': 62,
#                'latitude': -37.82,
#                'longitude': 142.323,
#                'surface_temperature_celsius': 54},
#               {'confidence': 93,
#                'latitude': -37.875,
#                'longitude': 142.51,
#                'surface_temperature_celsius': 73},
#               {'confidence': 84,
#                'latitude': -37.608,
#                'longitude': 149.328,
#                'surface_temperature_celsius': 55},
#               {'confidence': 95,
#                'latitude': -37.613,
#                'longitude': 149.305,
#                'surface_temperature_celsius': 75},
#               {'confidence': 59,
#                'latitude': -37.644,
#                'longitude': 149.346,
#                'surface_temperature_celsius': 55},
#               {'confidence': 90,
#                'latitude': -37.624,
#                'longitude': 149.314,
#                'surface_temperature_celsius': 66},
#               {'confidence': 75,
#                'latitude': -37.661,
#                'longitude': 149.327,
#                'surface_temperature_celsius': 56},
#               {'confidence': 79,
#                'latitude': -37.649,
#                'longitude': 149.322,
#                'surface_temperature_celsius': 60},
#               {'confidence': 93,
#                'latitude': -38.057,
#                'longitude': 144.211,
#                'surface_temperature_celsius': 73},
#               {'confidence': 60,
#                'latitude': -38.046,
#                'longitude': 144.201,
#                'surface_temperature_celsius': 48},
#               {'confidence': 82,
#                'latitude': -38.048,
#                'longitude': 144.213,
#                'surface_temperature_celsius': 55},
#               {'confidence': 82,
#                'latitude': -37.651,
#                'longitude': 149.345,
#                'surface_temperature_celsius': 64},
#               {'confidence': 53,
#                'latitude': -37.63,
#                'longitude': 149.335,
#                'surface_temperature_celsius': 57}]}
# {'_id': ObjectId('6650a2f9f374f529b6ea1848'),
#  'hotspots': [{'confidence': 78,
#                'latitude': -37.966,
#                'longitude': 145.051,
#                'surface_temperature_celsius': 68},
#               {'confidence': 82,
#                'latitude': -35.541,
#                'longitude': 143.311,
#                'surface_temperature_celsius': 63},
#               {'confidence': 67,
#                'latitude': -35.554,
#                'longitude': 143.307,
#                'surface_temperature_celsius': 53},
#               {'confidence': 86,
#                'latitude': -35.543,
#                'longitude': 143.316,
#                'surface_temperature_celsius': 67}]}

# %% [markdown]
# ## Task 2.2c
# - Finding the date, surface temperature (°C), air temperature (°C), relative humidity and maxwind speed on 15th and 16th of December 2023.

# %%
start = datetime.strptime("15/12/23", '%d/%m/%y')
end = datetime.strptime("16/12/23", '%d/%m/%y')


pprint(collection.find_one({"date": {"$gte":start, "$lte": end}}, {"date": 1, "air_temperature_celcius": 1, "hotspot.surface_temperature_celcius": 1, "max_wind_speed": 1,"relative_humidity":1}))
# Out:
# {'_id': ObjectId('6650a2f9f374f529b6ea183c'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 12, 15, 0, 0),
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}

# %% [markdown]
# ## Task 2.2d
# - Finding datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
pprint(collection.find_one({"hotspots.confidence": {"$gte":80, "$lte": 100}}, {"hotspots.datetime": 1, "air_temperature_celcius": 1, "hotspots.surface_temperature_celcius": 1, "max_wind_speed": 1,"hotspots.confidence":1}))
# Out:
# {'_id': ObjectId('6650a2f9f374f529b6ea1720'),
#  'air_temperature_celcius': 20,
#  'hotspots': [{'confidence': 87,
#                'datetime': datetime.datetime(2023, 3, 6, 5, 6, 30)},
#               {'confidence': 85,
#                'datetime': datetime.datetime(2023, 3, 6, 5, 6, 20)}],
#  'max_wind_speed': 21.0}

# %% [markdown]
# ## Task 2.2e
# - Finding the top 10 records with the highest surface temperature (°C)

# %%
results = collection.find().sort("hotspots.surface_temperature_celcius",-1).limit(10)
for result in results:
    pprint(result)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e8'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 9, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e9'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 10, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e4'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 5, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e7'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 8, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e5'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 6, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e3'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 4, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e1'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 2, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e0'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e2'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 3, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e6'),
#  'air_temperature_celcius': 32,
#  'date': datetime.datetime(2023, 7, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}

# %% [markdown]
# ## Task 2.2f
# - Finding the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
results = collection.aggregate([{"$project":{"_id":0, "date": 1, "count":{"$size":"$hotspots"}}}])
for result in results:
    pprint(result)
# Out:
# {'count': 0, 'date': datetime.datetime(2022, 12, 31, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 1, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 13, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 31, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 2, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 13, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 3, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 3, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 3, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 3, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 3, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 6, 3, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 7, 3, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 8, 3, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 9, 3, 0, 0)}
# {'count': 8, 'date': datetime.datetime(2023, 10, 3, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 3, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 12, 3, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 3, 13, 0, 0)}
# {'count': 10, 'date': datetime.datetime(2023, 3, 14, 0, 0)}
# {'count': 7, 'date': datetime.datetime(2023, 3, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 16, 0, 0)}
# {'count': 6, 'date': datetime.datetime(2023, 3, 17, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 3, 18, 0, 0)}
# {'count': 21, 'date': datetime.datetime(2023, 3, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 23, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 3, 24, 0, 0)}
# {'count': 13, 'date': datetime.datetime(2023, 3, 25, 0, 0)}
# {'count': 17, 'date': datetime.datetime(2023, 3, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 27, 0, 0)}
# {'count': 54, 'date': datetime.datetime(2023, 3, 28, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 3, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 30, 0, 0)}
# {'count': 22, 'date': datetime.datetime(2023, 3, 31, 0, 0)}
# {'count': 7, 'date': datetime.datetime(2023, 1, 4, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 2, 4, 0, 0)}
# {'count': 72, 'date': datetime.datetime(2023, 3, 4, 0, 0)}
# {'count': 89, 'date': datetime.datetime(2023, 4, 4, 0, 0)}
# {'count': 49, 'date': datetime.datetime(2023, 5, 4, 0, 0)}
# {'count': 118, 'date': datetime.datetime(2023, 6, 4, 0, 0)}
# {'count': 39, 'date': datetime.datetime(2023, 7, 4, 0, 0)}
# {'count': 20, 'date': datetime.datetime(2023, 8, 4, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 4, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 4, 0, 0)}
# {'count': 24, 'date': datetime.datetime(2023, 11, 4, 0, 0)}
# {'count': 69, 'date': datetime.datetime(2023, 12, 4, 0, 0)}
# {'count': 357, 'date': datetime.datetime(2023, 4, 13, 0, 0)}
# {'count': 18, 'date': datetime.datetime(2023, 4, 14, 0, 0)}
# {'count': 69, 'date': datetime.datetime(2023, 4, 15, 0, 0)}
# {'count': 18, 'date': datetime.datetime(2023, 4, 16, 0, 0)}
# {'count': 38, 'date': datetime.datetime(2023, 4, 17, 0, 0)}
# {'count': 325, 'date': datetime.datetime(2023, 4, 18, 0, 0)}
# {'count': 50, 'date': datetime.datetime(2023, 4, 19, 0, 0)}
# {'count': 31, 'date': datetime.datetime(2023, 4, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 21, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 4, 22, 0, 0)}
# {'count': 19, 'date': datetime.datetime(2023, 4, 23, 0, 0)}
# {'count': 8, 'date': datetime.datetime(2023, 4, 24, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 4, 25, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 4, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 28, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 4, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 30, 0, 0)}
# {'count': 20, 'date': datetime.datetime(2023, 1, 5, 0, 0)}
# {'count': 10, 'date': datetime.datetime(2023, 2, 5, 0, 0)}
# {'count': 64, 'date': datetime.datetime(2023, 3, 5, 0, 0)}
# {'count': 135, 'date': datetime.datetime(2023, 4, 5, 0, 0)}
# {'count': 31, 'date': datetime.datetime(2023, 5, 5, 0, 0)}
# {'count': 17, 'date': datetime.datetime(2023, 6, 5, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 7, 5, 0, 0)}
# {'count': 24, 'date': datetime.datetime(2023, 8, 5, 0, 0)}
# {'count': 13, 'date': datetime.datetime(2023, 9, 5, 0, 0)}
# {'count': 114, 'date': datetime.datetime(2023, 10, 5, 0, 0)}
# {'count': 19, 'date': datetime.datetime(2023, 11, 5, 0, 0)}
# {'count': 10, 'date': datetime.datetime(2023, 12, 5, 0, 0)}
# {'count': 54, 'date': datetime.datetime(2023, 5, 13, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 5, 14, 0, 0)}
# {'count': 102, 'date': datetime.datetime(2023, 5, 15, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 5, 16, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 5, 17, 0, 0)}
# {'count': 7, 'date': datetime.datetime(2023, 5, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 21, 0, 0)}
# {'count': 33, 'date': datetime.datetime(2023, 5, 22, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 5, 23, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 5, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 25, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 5, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 31, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 1, 6, 0, 0)}
# {'count': 11, 'date': datetime.datetime(2023, 2, 6, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 3, 6, 0, 0)}
# {'count': 9, 'date': datetime.datetime(2023, 4, 6, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 6, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 6, 0, 0)}
# {'count': 14, 'date': datetime.datetime(2023, 7, 6, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 6, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 9, 6, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 6, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 11, 6, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 6, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 6, 13, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 6, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 15, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 6, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 17, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 6, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 19, 0, 0)}
# {'count': 6, 'date': datetime.datetime(2023, 6, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 21, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 6, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 29, 0, 0)}
# {'count': 6, 'date': datetime.datetime(2023, 6, 30, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 1, 7, 0, 0)}
# {'count': 8, 'date': datetime.datetime(2023, 2, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 7, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 4, 7, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 5, 7, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 6, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 7, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 13, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 7, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 28, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 7, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 30, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 7, 31, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 1, 8, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 2, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 8, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 5, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 8, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 10, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 8, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 8, 0, 0)}
# {'count': 9, 'date': datetime.datetime(2023, 8, 13, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 8, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 20, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 31, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 8, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 9, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 10, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 9, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 13, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 19, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 9, 20, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 9, 21, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 9, 22, 0, 0)}
# {'count': 23, 'date': datetime.datetime(2023, 9, 23, 0, 0)}
# {'count': 28, 'date': datetime.datetime(2023, 9, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 25, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 9, 26, 0, 0)}
# {'count': 7, 'date': datetime.datetime(2023, 9, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 28, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 9, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 9, 30, 0, 0)}
# {'count': 8, 'date': datetime.datetime(2023, 1, 10, 0, 0)}
# {'count': 7, 'date': datetime.datetime(2023, 2, 10, 0, 0)}
# {'count': 18, 'date': datetime.datetime(2023, 3, 10, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 4, 10, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 10, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 6, 10, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 7, 10, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 8, 10, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 9, 10, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 10, 10, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 10, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 10, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 13, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 14, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 10, 15, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 10, 16, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 10, 17, 0, 0)}
# {'count': 6, 'date': datetime.datetime(2023, 10, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 19, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 10, 20, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 10, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 22, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 10, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 25, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 10, 26, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 10, 27, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 10, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 31, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 11, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 5, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 11, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 8, 11, 0, 0)}
# {'count': 10, 'date': datetime.datetime(2023, 9, 11, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 10, 11, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 11, 11, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 12, 11, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 11, 13, 0, 0)}
# {'count': 3, 'date': datetime.datetime(2023, 11, 14, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 15, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 20, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 11, 21, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 11, 22, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 11, 23, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 24, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 26, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 27, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 11, 28, 0, 0)}
# {'count': 8, 'date': datetime.datetime(2023, 11, 29, 0, 0)}
# {'count': 31, 'date': datetime.datetime(2023, 11, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 1, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 2, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 3, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 4, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 5, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 6, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 7, 12, 0, 0)}
# {'count': 5, 'date': datetime.datetime(2023, 8, 12, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 9, 12, 0, 0)}
# {'count': 2, 'date': datetime.datetime(2023, 10, 12, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 11, 12, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 12, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 13, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 14, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 12, 15, 0, 0)}
# {'count': 15, 'date': datetime.datetime(2023, 12, 16, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 17, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 18, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 19, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 20, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 21, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 22, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 23, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 24, 0, 0)}
# {'count': 1, 'date': datetime.datetime(2023, 12, 25, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 26, 0, 0)}
# {'count': 4, 'date': datetime.datetime(2023, 12, 27, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 28, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 29, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 30, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2023, 12, 31, 0, 0)}
# {'count': 0, 'date': datetime.datetime(2024, 1, 1, 0, 0)}

# %% [markdown]
# ## Task 2.2g
# - Finding the records of fires where the confidence is below 70

# %%
results = collection.aggregate([{"$unwind": "$hotspots"},{"$match": {"hotspots.confidence": {"$lt": 70}}},{"$project": {"_id": 0,"date": 1,"records": "$hotspots"}}])

for result in results:
    pprint(result)
# Out:
# {'date': datetime.datetime(2023, 8, 3, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 3, 8, 4, 51),
#              'latitude': -37.7885,
#              'longitude': 141.9352,
#              'surface_temperature_celsius': 55}}
# {'date': datetime.datetime(2023, 9, 3, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 3, 9, 3, 57),
#              'latitude': -37.7171,
#              'longitude': 147.5866,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 10, 3, 0, 0),
#  'records': {'confidence': 55,
#              'datetime': datetime.datetime(2023, 3, 10, 4, 43),
#              'latitude': -36.2544,
#              'longitude': 148.0353,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 10, 3, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 3, 10, 4, 42, 30),
#              'latitude': -37.2197,
#              'longitude': 147.9621,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 13, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 3, 13, 23, 58, 50),
#              'latitude': -37.0286,
#              'longitude': 148.155,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 3, 13, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 3, 13, 12, 57),
#              'latitude': -37.0316,
#              'longitude': 148.1519,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 3, 15, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 3, 15, 0, 42, 50),
#              'latitude': -37.4075,
#              'longitude': 147.0233,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 15, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 3, 15, 0, 42, 50),
#              'latitude': -37.0228,
#              'longitude': 148.1281,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 15, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 3, 15, 0, 42, 40),
#              'latitude': -37.002,
#              'longitude': 148.2055,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 18, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 3, 18, 13, 16, 50),
#              'latitude': -37.4313,
#              'longitude': 147.0343,
#              'surface_temperature_celsius': 37}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 39, 20),
#              'latitude': -37.9164,
#              'longitude': 143.4866,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 39, 20),
#              'latitude': -37.9257,
#              'longitude': 143.4891,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 36),
#              'latitude': -37.3982,
#              'longitude': 147.0001,
#              'surface_temperature_celsius': 58}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 35),
#              'latitude': -37.4023,
#              'longitude': 147.0394,
#              'surface_temperature_celsius': 56}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 33, 50),
#              'latitude': -37.4336,
#              'longitude': 147.0534,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 33, 30),
#              'latitude': -37.4003,
#              'longitude': 147.0448,
#              'surface_temperature_celsius': 55}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 33, 30),
#              'latitude': -37.9184,
#              'longitude': 143.4745,
#              'surface_temperature_celsius': 55}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 33, 10),
#              'latitude': -37.3911,
#              'longitude': 147.037,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 3, 19, 4, 32, 50),
#              'latitude': -37.9277,
#              'longitude': 143.477,
#              'surface_temperature_celsius': 55}}
# {'date': datetime.datetime(2023, 3, 19, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 3, 19, 0, 12, 50),
#              'latitude': -37.3942,
#              'longitude': 147.0455,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 24, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 3, 24, 4, 58),
#              'latitude': -37.1603,
#              'longitude': 142.8088,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 3, 24, 0, 0),
#  'records': {'confidence': 55,
#              'datetime': datetime.datetime(2023, 3, 24, 4, 56, 10),
#              'latitude': -37.1684,
#              'longitude': 142.8183,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 3, 25, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 3, 25, 4, 3, 10),
#              'latitude': -37.8992,
#              'longitude': 143.4534,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 3, 25, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 3, 25, 3, 56, 40),
#              'latitude': -37.9022,
#              'longitude': 143.4607,
#              'surface_temperature_celsius': 57}}
# {'date': datetime.datetime(2023, 3, 26, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 3, 26, 4, 41, 10),
#              'latitude': -38.1131,
#              'longitude': 143.7173,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 26, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 3, 26, 4, 39, 10),
#              'latitude': -37.8469,
#              'longitude': 143.5343,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 3, 26, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 3, 26, 4, 39, 10),
#              'latitude': -37.1956,
#              'longitude': 141.0252,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 28, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 3, 28, 4, 29, 30),
#              'latitude': -37.6195,
#              'longitude': 143.4212,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 3, 28, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 3, 28, 4, 26, 50),
#              'latitude': -37.6376,
#              'longitude': 143.4255,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 3, 28, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 3, 28, 4, 26, 50),
#              'latitude': -36.4422,
#              'longitude': 141.4172,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 3, 28, 0, 0),
#  'records': {'confidence': 55,
#              'datetime': datetime.datetime(2023, 3, 28, 4, 26, 50),
#              'latitude': -34.342,
#              'longitude': 141.6548,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 3, 29, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 3, 29, 0, 48, 40),
#              'latitude': -34.2648,
#              'longitude': 141.6325,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 50),
#              'latitude': -36.1649,
#              'longitude': 145.9352,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 40),
#              'latitude': -36.0436,
#              'longitude': 145.7964,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 10),
#              'latitude': -36.7134,
#              'longitude': 145.2151,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 10),
#              'latitude': -36.7028,
#              'longitude': 145.2519,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 10),
#              'latitude': -37.561,
#              'longitude': 143.242,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 3, 31, 4, 57, 10),
#              'latitude': -37.982,
#              'longitude': 143.6422,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 3, 31, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 3, 31, 0, 36, 30),
#              'latitude': -34.2568,
#              'longitude': 141.64,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 1, 4, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 4, 1, 4, 2, 40),
#              'latitude': -36.2044,
#              'longitude': 145.7706,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 1, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 1, 4, 2, 40),
#              'latitude': -36.5245,
#              'longitude': 143.1556,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 1, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 1, 4, 2, 40),
#              'latitude': -36.1002,
#              'longitude': 147.6494,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 2, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 2, 4, 53, 30),
#              'latitude': -36.3872,
#              'longitude': 145.3858,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 2, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 2, 4, 45, 10),
#              'latitude': -36.494,
#              'longitude': 145.4522,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 2, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 2, 0, 24, 50),
#              'latitude': -37.324,
#              'longitude': 146.1647,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 53, 50),
#              'latitude': -37.8668,
#              'longitude': 143.0472,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 53, 40),
#              'latitude': -37.7602,
#              'longitude': 143.382,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 53, 30),
#              'latitude': -37.7885,
#              'longitude': 142.9509,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 52, 10),
#              'latitude': -37.8717,
#              'longitude': 143.2566,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 51, 10),
#              'latitude': -37.8011,
#              'longitude': 144.7343,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 50),
#              'latitude': -37.0241,
#              'longitude': 141.5163,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 50),
#              'latitude': -37.2912,
#              'longitude': 143.543,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 50),
#              'latitude': -37.313,
#              'longitude': 146.1561,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 50),
#              'latitude': -38.0226,
#              'longitude': 143.6739,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 40),
#              'latitude': -37.8089,
#              'longitude': 145.9555,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 40),
#              'latitude': -37.9009,
#              'longitude': 143.6217,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 40),
#              'latitude': -37.7836,
#              'longitude': 142.9437,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 40),
#              'latitude': -37.0484,
#              'longitude': 141.6245,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 3, 3, 50, 40),
#              'latitude': -36.911,
#              'longitude': 142.1445,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 3, 1, 11),
#              'latitude': -34.2536,
#              'longitude': 141.6199,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 3, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 3, 1, 7),
#              'latitude': -34.2614,
#              'longitude': 141.6412,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 4, 15, 30, 40),
#              'latitude': -36.0933,
#              'longitude': 141.7154,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 39, 50),
#              'latitude': -36.6281,
#              'longitude': 142.4349,
#              'surface_temperature_celsius': 68}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 39, 40),
#              'latitude': -36.937,
#              'longitude': 142.1176,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 38, 10),
#              'latitude': -36.6951,
#              'longitude': 145.424,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 36, 30),
#              'latitude': -37.6714,
#              'longitude': 144.2154,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 36, 30),
#              'latitude': -38.0494,
#              'longitude': 143.9141,
#              'surface_temperature_celsius': 58}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 34, 20),
#              'latitude': -38.4879,
#              'longitude': 143.9971,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 33, 30),
#              'latitude': -37.1744,
#              'longitude': 143.9256,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 33, 30),
#              'latitude': -36.4918,
#              'longitude': 142.2465,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 33, 10),
#              'latitude': -36.6299,
#              'longitude': 142.4234,
#              'surface_temperature_celsius': 71}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 33, 10),
#              'latitude': -36.1439,
#              'longitude': 145.832,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 50),
#              'latitude': -36.7009,
#              'longitude': 141.541,
#              'surface_temperature_celsius': 49}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 55,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -36.4611,
#              'longitude': 143.146,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -36.3539,
#              'longitude': 142.1894,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -37.0081,
#              'longitude': 141.7654,
#              'surface_temperature_celsius': 62}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -36.2889,
#              'longitude': 141.7692,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -36.6228,
#              'longitude': 142.428,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 4, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 4, 4, 32, 40),
#              'latitude': -38.1177,
#              'longitude': 143.6409,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 5, 13, 10, 10),
#              'latitude': -38.3499,
#              'longitude': 147.033,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 5, 13, 2, 40),
#              'latitude': -37.6435,
#              'longitude': 146.1417,
#              'surface_temperature_celsius': 36}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 5, 5, 15, 40),
#              'latitude': -37.7522,
#              'longitude': 142.3183,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 5, 5, 15, 30),
#              'latitude': -36.9396,
#              'longitude': 141.9303,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 45, 10),
#              'latitude': -37.78,
#              'longitude': 141.8091,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 44, 40),
#              'latitude': -37.7767,
#              'longitude': 141.8127,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 44, 30),
#              'latitude': -38.1756,
#              'longitude': 143.9829,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 40, 30),
#              'latitude': -38.3553,
#              'longitude': 147.0231,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 40, 30),
#              'latitude': -36.934,
#              'longitude': 142.5759,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 39, 10),
#              'latitude': -38.0383,
#              'longitude': 144.4307,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 39, 10),
#              'latitude': -36.9354,
#              'longitude': 142.5807,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 39, 10),
#              'latitude': -36.9405,
#              'longitude': 142.8627,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 5, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 5, 3, 39, 10),
#              'latitude': -37.6339,
#              'longitude': 143.4108,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 25, 40),
#              'latitude': -37.7069,
#              'longitude': 142.1573,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 25, 40),
#              'latitude': -36.0834,
#              'longitude': 146.5364,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 23, 50),
#              'latitude': -36.3557,
#              'longitude': 141.3268,
#              'surface_temperature_celsius': 52}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 23, 50),
#              'latitude': -37.6104,
#              'longitude': 147.8367,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 23, 50),
#              'latitude': -37.9229,
#              'longitude': 143.647,
#              'surface_temperature_celsius': 63}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 23, 50),
#              'latitude': -37.5052,
#              'longitude': 142.8636,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 22, 20),
#              'latitude': -37.8177,
#              'longitude': 142.9168,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 21, 20),
#              'latitude': -37.5842,
#              'longitude': 148.5717,
#              'surface_temperature_celsius': 49}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 21),
#              'latitude': -38.0089,
#              'longitude': 143.8976,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 21),
#              'latitude': -37.3072,
#              'longitude': 147.5003,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 50),
#              'latitude': -37.3556,
#              'longitude': 146.1085,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.6806,
#              'longitude': 143.2676,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.7212,
#              'longitude': 145.9754,
#              'surface_temperature_celsius': 52}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -38.3343,
#              'longitude': 143.8644,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -35.723,
#              'longitude': 142.063,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -35.1383,
#              'longitude': 141.8172,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -36.4133,
#              'longitude': 141.0286,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -36.6492,
#              'longitude': 142.3976,
#              'surface_temperature_celsius': 60}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -36.0765,
#              'longitude': 146.4896,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -36.0799,
#              'longitude': 146.529,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -36.8632,
#              'longitude': 142.5802,
#              'surface_temperature_celsius': 60}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.1929,
#              'longitude': 143.8132,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.1992,
#              'longitude': 146.2301,
#              'surface_temperature_celsius': 60}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.5914,
#              'longitude': 148.5807,
#              'surface_temperature_celsius': 61}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 6, 4, 20, 40),
#              'latitude': -37.7496,
#              'longitude': 148.3898,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 6, 0, 3, 50),
#              'latitude': -35.4625,
#              'longitude': 143.1486,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 6, 4, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 4, 6, 0, 1, 40),
#              'latitude': -38.0942,
#              'longitude': 146.9603,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 53, 40),
#              'latitude': -35.6961,
#              'longitude': 143.1935,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 52, 10),
#              'latitude': -37.3314,
#              'longitude': 149.1283,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 51, 20),
#              'latitude': -37.3359,
#              'longitude': 149.3816,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 51),
#              'latitude': -37.3526,
#              'longitude': 149.3972,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 50, 40),
#              'latitude': -37.3344,
#              'longitude': 149.3933,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 50, 40),
#              'latitude': -37.3511,
#              'longitude': 149.4088,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 7, 12, 50, 40),
#              'latitude': -36.7508,
#              'longitude': 147.1254,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 7, 5, 3, 10),
#              'latitude': -36.1031,
#              'longitude': 143.0782,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 7, 5, 3, 10),
#              'latitude': -36.1025,
#              'longitude': 143.0825,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 7, 5, 3, 10),
#              'latitude': -36.7314,
#              'longitude': 141.8698,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 7, 3, 31, 40),
#              'latitude': -37.7931,
#              'longitude': 148.385,
#              'surface_temperature_celsius': 58}}
# {'date': datetime.datetime(2023, 7, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 7, 3, 27, 50),
#              'latitude': -37.7974,
#              'longitude': 148.5498,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 15, 20),
#              'latitude': -37.34,
#              'longitude': 149.3668,
#              'surface_temperature_celsius': 74}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 14, 40),
#              'latitude': -37.8567,
#              'longitude': 147.1576,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 12, 20),
#              'latitude': -37.4368,
#              'longitude': 149.1191,
#              'surface_temperature_celsius': 52}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 11, 40),
#              'latitude': -37.9408,
#              'longitude': 146.0611,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 9, 20),
#              'latitude': -37.6994,
#              'longitude': 146.2162,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 8, 50),
#              'latitude': -36.7199,
#              'longitude': 142.5844,
#              'surface_temperature_celsius': 56}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 8, 40),
#              'latitude': -37.3493,
#              'longitude': 149.3691,
#              'surface_temperature_celsius': 80}}
# {'date': datetime.datetime(2023, 8, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 8, 4, 8, 40),
#              'latitude': -37.6447,
#              'longitude': 148.6039,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 50, 20),
#              'latitude': -36.2282,
#              'longitude': 145.9074,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 42, 10),
#              'latitude': -36.3499,
#              'longitude': 146.1402,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 40, 30),
#              'latitude': -36.4439,
#              'longitude': 145.8846,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 39, 40),
#              'latitude': -36.0818,
#              'longitude': 146.5461,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.343,
#              'longitude': 143.3479,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.1751,
#              'longitude': 142.7831,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 55,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.4606,
#              'longitude': 141.0562,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 66,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.0156,
#              'longitude': 143.2188,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.1398,
#              'longitude': 141.7793,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -35.2068,
#              'longitude': 143.2912,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.3579,
#              'longitude': 146.1268,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 11, 4, 38, 50),
#              'latitude': -36.0787,
#              'longitude': 146.5728,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 11, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 11, 0, 20, 30),
#              'latitude': -37.9796,
#              'longitude': 146.8024,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 12, 13, 13, 10),
#              'latitude': -35.4309,
#              'longitude': 142.3626,
#              'surface_temperature_celsius': 36}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 12, 13, 9, 20),
#              'latitude': -35.4407,
#              'longitude': 142.3644,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 28),
#              'latitude': -37.4755,
#              'longitude': 142.6339,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 26, 50),
#              'latitude': -36.7453,
#              'longitude': 141.4578,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 25),
#              'latitude': -36.7038,
#              'longitude': 141.0498,
#              'surface_temperature_celsius': 39}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 21, 50),
#              'latitude': -37.7578,
#              'longitude': 142.227,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 21, 40),
#              'latitude': -36.8083,
#              'longitude': 142.0219,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 4, 12, 5, 21, 40),
#              'latitude': -36.714,
#              'longitude': 141.1485,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 51),
#              'latitude': -36.6385,
#              'longitude': 142.5297,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 50, 10),
#              'latitude': -36.9179,
#              'longitude': 141.3095,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 46, 50),
#              'latitude': -37.3654,
#              'longitude': 143.8156,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 46, 20),
#              'latitude': -36.6188,
#              'longitude': 144.0402,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 46),
#              'latitude': -37.4047,
#              'longitude': 143.6615,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 46),
#              'latitude': -36.2367,
#              'longitude': 141.3998,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 45, 10),
#              'latitude': -36.5234,
#              'longitude': 144.6939,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 45),
#              'latitude': -36.6803,
#              'longitude': 141.0957,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 50),
#              'latitude': -36.7866,
#              'longitude': 142.1989,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.6292,
#              'longitude': 143.8862,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -35.7937,
#              'longitude': 143.195,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 57,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.9142,
#              'longitude': 141.3013,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.6306,
#              'longitude': 143.8908,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -37.3586,
#              'longitude': 142.9087,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.9524,
#              'longitude': 143.7501,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -37.0643,
#              'longitude': 141.8567,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.2403,
#              'longitude': 141.4047,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -36.6776,
#              'longitude': 141.0877,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -37.7929,
#              'longitude': 143.1197,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -37.7972,
#              'longitude': 143.1153,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 12, 4, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 4, 12, 3, 44, 40),
#              'latitude': -37.3656,
#              'longitude': 143.8206,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 4, 13, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 4, 13, 4, 36, 30),
# ...
#              'longitude': 148.113,
#              'surface_temperature_celsius': 52}}
# {'date': datetime.datetime(2023, 2, 10, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 10, 2, 23, 44, 31),
#              'latitude': -37.466,
#              'longitude': 148.1,
#              'surface_temperature_celsius': 29}}
# {'date': datetime.datetime(2023, 2, 10, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 10, 2, 4, 53, 10),
#              'latitude': -37.475,
#              'longitude': 148.134,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 2, 10, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 10, 2, 0, 39, 34),
#              'latitude': -37.456,
#              'longitude': 148.11,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 3, 10, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 10, 3, 15, 1, 44),
#              'latitude': -37.461,
#              'longitude': 148.109,
#              'surface_temperature_celsius': 33}}
# {'date': datetime.datetime(2023, 3, 10, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 10, 3, 3, 58, 28),
#              'latitude': -37.236,
#              'longitude': 141.176,
#              'surface_temperature_celsius': 37}}
# {'date': datetime.datetime(2023, 3, 10, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 10, 3, 3, 58, 28),
#              'latitude': -37.227,
#              'longitude': 141.151,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 3, 10, 0, 0),
#  'records': {'confidence': 54,
#              'datetime': datetime.datetime(2023, 10, 3, 1, 22, 44),
#              'latitude': -37.227,
#              'longitude': 141.146,
#              'surface_temperature_celsius': 31}}
# {'date': datetime.datetime(2023, 4, 10, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 10, 4, 4, 41, 36),
#              'latitude': -36.418,
#              'longitude': 141.596,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 10, 16, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 10, 16, 23, 56, 43),
#              'latitude': -37.288,
#              'longitude': 144.39,
#              'surface_temperature_celsius': 36}}
# {'date': datetime.datetime(2023, 10, 17, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 10, 17, 4, 10, 38),
#              'latitude': -37.587,
#              'longitude': 142.479,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 10, 20, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 10, 20, 0, 27, 12),
#              'latitude': -37.296,
#              'longitude': 144.386,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 10, 21, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 10, 21, 1, 9, 54),
#              'latitude': -36.1,
#              'longitude': 143.772,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 10, 26, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 10, 26, 4, 4, 53),
#              'latitude': -36.156,
#              'longitude': 143.568,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 10, 26, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 10, 26, 4, 4, 53),
#              'latitude': -36.152,
#              'longitude': 143.578,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 10, 27, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 10, 27, 4, 47, 31),
#              'latitude': -36.748,
#              'longitude': 144.168,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 8, 11, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 11, 8, 5, 12, 8),
#              'latitude': -36.538,
#              'longitude': 141.129,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 9, 11, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 11, 9, 4, 16, 56),
#              'latitude': -36.759,
#              'longitude': 145.179,
#              'surface_temperature_celsius': 52}}
# {'date': datetime.datetime(2023, 9, 11, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 11, 9, 4, 16, 56),
#              'latitude': -36.758,
#              'longitude': 145.19,
#              'surface_temperature_celsius': 51}}
# {'date': datetime.datetime(2023, 9, 11, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 11, 9, 4, 16, 46),
#              'latitude': -37.719,
#              'longitude': 142.154,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 11, 11, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 11, 11, 15, 8),
#              'latitude': -36.943,
#              'longitude': 143.286,
#              'surface_temperature_celsius': 29}}
# {'date': datetime.datetime(2023, 12, 11, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 11, 12, 4, 47, 32),
#              'latitude': -36.942,
#              'longitude': 143.282,
#              'surface_temperature_celsius': 53}}
# {'date': datetime.datetime(2023, 12, 11, 0, 0),
#  'records': {'confidence': 58,
#              'datetime': datetime.datetime(2023, 11, 12, 4, 47, 16),
#              'latitude': -37.864,
#              'longitude': 144.174,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 12, 11, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 11, 12, 4, 46, 53),
#              'latitude': -38.912,
#              'longitude': 146.272,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 12, 11, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 11, 12, 0, 33, 15),
#              'latitude': -36.942,
#              'longitude': 143.292,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 11, 13, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 13, 3, 52, 8),
#              'latitude': -37.954,
#              'longitude': 143.918,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 13, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 11, 13, 1, 16, 38),
#              'latitude': -38.167,
#              'longitude': 143.841,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 11, 13, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 11, 13, 1, 16, 37),
#              'latitude': -38.16,
#              'longitude': 143.803,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 11, 14, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 14, 0, 21, 26),
#              'latitude': -38.527,
#              'longitude': 143.493,
#              'surface_temperature_celsius': 45}}
# {'date': datetime.datetime(2023, 11, 14, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 14, 0, 21, 7),
#              'latitude': -37.332,
#              'longitude': 143.375,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 11, 23, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 11, 23, 0, 15, 12),
#              'latitude': -38.141,
#              'longitude': 143.183,
#              'surface_temperature_celsius': 46}}
# {'date': datetime.datetime(2023, 11, 23, 0, 0),
#  'records': {'confidence': 63,
#              'datetime': datetime.datetime(2023, 11, 23, 0, 14, 47),
#              'latitude': -36.952,
#              'longitude': 144.972,
#              'surface_temperature_celsius': 60}}
# {'date': datetime.datetime(2023, 11, 28, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 11, 28, 0, 33, 14),
#              'latitude': -37.749,
#              'longitude': 148.297,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 29, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 11, 29, 13, 17, 24),
#              'latitude': -37.611,
#              'longitude': 149.277,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 11, 29, 0, 0),
#  'records': {'confidence': 68,
#              'datetime': datetime.datetime(2023, 11, 29, 13, 17, 24),
#              'latitude': -37.605,
#              'longitude': 149.308,
#              'surface_temperature_celsius': 43}}
# {'date': datetime.datetime(2023, 11, 29, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 11, 29, 3, 53, 16),
#              'latitude': -34.282,
#              'longitude': 142.121,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 11, 29, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 29, 3, 52, 10),
#              'latitude': -37.605,
#              'longitude': 149.326,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 52,
#              'datetime': datetime.datetime(2023, 11, 30, 23, 25, 57),
#              'latitude': -37.635,
#              'longitude': 149.303,
#              'surface_temperature_celsius': 47}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 11, 30, 15, 38, 36),
#              'latitude': -37.59,
#              'longitude': 149.31,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 30, 15, 38, 36),
#              'latitude': -37.633,
#              'longitude': 149.264,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 11, 30, 15, 38, 35),
#              'latitude': -37.58,
#              'longitude': 149.331,
#              'surface_temperature_celsius': 35}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 61,
#              'datetime': datetime.datetime(2023, 11, 30, 15, 38, 32),
#              'latitude': -37.38,
#              'longitude': 149.334,
#              'surface_temperature_celsius': 31}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#              'latitude': -37.602,
#              'longitude': 149.295,
#              'surface_temperature_celsius': 33}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#              'latitude': -37.598,
#              'longitude': 149.29,
#              'surface_temperature_celsius': 32}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#              'latitude': -37.61,
#              'longitude': 149.279,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 11, 30, 0, 21),
#              'latitude': -37.637,
#              'longitude': 146.288,
#              'surface_temperature_celsius': 42}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#              'latitude': -37.6,
#              'longitude': 149.297,
#              'surface_temperature_celsius': 50}}
# {'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'records': {'confidence': 64,
#              'datetime': datetime.datetime(2023, 11, 30, 0, 20, 49),
#              'latitude': -37.382,
#              'longitude': 149.341,
#              'surface_temperature_celsius': 41}}
# {'date': datetime.datetime(2023, 8, 12, 0, 0),
#  'records': {'confidence': 56,
#              'datetime': datetime.datetime(2023, 12, 8, 13, 11, 43),
#              'latitude': -36.291,
#              'longitude': 146.159,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 10, 12, 0, 0),
#  'records': {'confidence': 50,
#              'datetime': datetime.datetime(2023, 12, 10, 0, 57, 59),
#              'latitude': -37.987,
#              'longitude': 144.005,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 10, 12, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 12, 10, 0, 56, 57),
#              'latitude': -34.289,
#              'longitude': 141.712,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 12, 12, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 12, 12, 0, 45, 38),
#              'latitude': -37.903,
#              'longitude': 145.25,
#              'surface_temperature_celsius': 44}}
# {'date': datetime.datetime(2023, 12, 15, 0, 0),
#  'records': {'confidence': 51,
#              'datetime': datetime.datetime(2023, 12, 15, 13, 17, 17),
#              'latitude': -37.623,
#              'longitude': 149.323,
#              'surface_temperature_celsius': 38}}
# {'date': datetime.datetime(2023, 12, 15, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 12, 15, 1, 16, 23),
#              'latitude': -38.038,
#              'longitude': 142.986,
#              'surface_temperature_celsius': 40}}
# {'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'records': {'confidence': 69,
#              'datetime': datetime.datetime(2023, 12, 16, 15, 38, 39),
#              'latitude': -37.624,
#              'longitude': 149.332,
#              'surface_temperature_celsius': 33}}
# {'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'records': {'confidence': 62,
#              'datetime': datetime.datetime(2023, 12, 16, 4, 35, 15),
#              'latitude': -37.82,
#              'longitude': 142.323,
#              'surface_temperature_celsius': 54}}
# {'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'records': {'confidence': 59,
#              'datetime': datetime.datetime(2023, 12, 16, 4, 34, 57),
#              'latitude': -37.644,
#              'longitude': 149.346,
#              'surface_temperature_celsius': 55}}
# {'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'records': {'confidence': 60,
#              'datetime': datetime.datetime(2023, 12, 16, 0, 21, 11),
#              'latitude': -38.046,
#              'longitude': 144.201,
#              'surface_temperature_celsius': 48}}
# {'date': datetime.datetime(2023, 12, 16, 0, 0),
#  'records': {'confidence': 53,
#              'datetime': datetime.datetime(2023, 12, 16, 0, 20, 53),
#              'latitude': -37.63,
#              'longitude': 149.335,
#              'surface_temperature_celsius': 57}}
# {'date': datetime.datetime(2023, 12, 24, 0, 0),
#  'records': {'confidence': 65,
#              'datetime': datetime.datetime(2023, 12, 24, 13, 12, 1),
#              'latitude': -35.646,
#              'longitude': 142.282,
#              'surface_temperature_celsius': 32}}
# {'date': datetime.datetime(2023, 12, 27, 0, 0),
#  'records': {'confidence': 67,
#              'datetime': datetime.datetime(2023, 12, 27, 0, 2, 15),
#              'latitude': -35.554,
#              'longitude': 143.307,
#              'surface_temperature_celsius': 53}}

# %% [markdown]
# ## Task 2.2h
# - Finding the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.

# %%
results = collection.aggregate([{"$unwind": "$hotspots"},{"$group": {"_id": "$date", "avg": {"$avg": "$hotspots.surface_temperature_celsius"}}}])

for result in results:
    pprint(result)
# Out:
# {'_id': datetime.datetime(2023, 3, 15, 0, 0), 'avg': 46.0}
# {'_id': datetime.datetime(2023, 4, 24, 0, 0), 'avg': 59.375}
# {'_id': datetime.datetime(2023, 4, 26, 0, 0), 'avg': 34.0}
# {'_id': datetime.datetime(2023, 12, 13, 0, 0), 'avg': 60.0}
# {'_id': datetime.datetime(2023, 4, 17, 0, 0), 'avg': 50.921052631578945}
# {'_id': datetime.datetime(2023, 9, 26, 0, 0), 'avg': 33.0}
# {'_id': datetime.datetime(2023, 10, 10, 0, 0), 'avg': 53.333333333333336}
# {'_id': datetime.datetime(2023, 3, 28, 0, 0), 'avg': 60.925925925925924}
# {'_id': datetime.datetime(2023, 11, 23, 0, 0), 'avg': 58.8}
# {'_id': datetime.datetime(2023, 9, 21, 0, 0), 'avg': 40.5}
# {'_id': datetime.datetime(2023, 10, 16, 0, 0), 'avg': 36.0}
# {'_id': datetime.datetime(2023, 4, 25, 0, 0), 'avg': 48.666666666666664}
# {'_id': datetime.datetime(2023, 10, 23, 0, 0), 'avg': 38.0}
# {'_id': datetime.datetime(2023, 3, 29, 0, 0), 'avg': 51.0}
# {'_id': datetime.datetime(2023, 3, 6, 0, 0), 'avg': 47.0}
# {'_id': datetime.datetime(2023, 11, 14, 0, 0), 'avg': 52.0}
# {'_id': datetime.datetime(2023, 10, 12, 0, 0), 'avg': 46.0}
# {'_id': datetime.datetime(2023, 3, 18, 0, 0), 'avg': 79.33333333333333}
# {'_id': datetime.datetime(2023, 4, 19, 0, 0), 'avg': 54.16}
# {'_id': datetime.datetime(2023, 5, 16, 0, 0), 'avg': 39.666666666666664}
# {'_id': datetime.datetime(2023, 12, 12, 0, 0), 'avg': 44.0}
# {'_id': datetime.datetime(2023, 6, 7, 0, 0), 'avg': 56.0}
# {'_id': datetime.datetime(2023, 10, 5, 0, 0), 'avg': 52.86842105263158}
# {'_id': datetime.datetime(2023, 6, 3, 0, 0), 'avg': 60.5}
# {'_id': datetime.datetime(2023, 11, 30, 0, 0), 'avg': 52.41935483870968}
# {'_id': datetime.datetime(2023, 11, 6, 0, 0), 'avg': 41.5}
# {'_id': datetime.datetime(2023, 9, 22, 0, 0), 'avg': 45.0}
# {'_id': datetime.datetime(2023, 4, 29, 0, 0), 'avg': 63.0}
# {'_id': datetime.datetime(2023, 2, 8, 0, 0), 'avg': 63.5}
# {'_id': datetime.datetime(2023, 5, 5, 0, 0), 'avg': 51.70967741935484}
# {'_id': datetime.datetime(2023, 10, 21, 0, 0), 'avg': 51.25}
# {'_id': datetime.datetime(2023, 4, 20, 0, 0), 'avg': 56.58064516129032}
# {'_id': datetime.datetime(2023, 2, 5, 0, 0), 'avg': 55.6}
# {'_id': datetime.datetime(2023, 9, 29, 0, 0), 'avg': 43.0}
# {'_id': datetime.datetime(2023, 12, 11, 0, 0), 'avg': 53.0}
# {'_id': datetime.datetime(2023, 2, 6, 0, 0), 'avg': 47.72727272727273}
# {'_id': datetime.datetime(2023, 3, 19, 0, 0), 'avg': 65.57142857142857}
# {'_id': datetime.datetime(2023, 5, 26, 0, 0), 'avg': 49.5}
# {'_id': datetime.datetime(2023, 4, 13, 0, 0), 'avg': 58.57983193277311}
# {'_id': datetime.datetime(2023, 3, 26, 0, 0), 'avg': 56.88235294117647}
# {'_id': datetime.datetime(2023, 8, 12, 0, 0), 'avg': 50.6}
# {'_id': datetime.datetime(2023, 6, 10, 0, 0), 'avg': 44.0}
# {'_id': datetime.datetime(2023, 10, 9, 0, 0), 'avg': 56.5}
# {'_id': datetime.datetime(2023, 12, 16, 0, 0), 'avg': 57.8}
# {'_id': datetime.datetime(2023, 4, 22, 0, 0), 'avg': 54.5}
# {'_id': datetime.datetime(2023, 5, 23, 0, 0), 'avg': 51.2}
# {'_id': datetime.datetime(2023, 1, 6, 0, 0), 'avg': 54.0}
# {'_id': datetime.datetime(2023, 2, 4, 0, 0), 'avg': 45.2}
# {'_id': datetime.datetime(2023, 12, 24, 0, 0), 'avg': 32.0}
# {'_id': datetime.datetime(2023, 12, 3, 0, 0), 'avg': 88.2}
# {'_id': datetime.datetime(2023, 11, 22, 0, 0), 'avg': 61.5}
# {'_id': datetime.datetime(2023, 1, 10, 0, 0), 'avg': 48.25}
# {'_id': datetime.datetime(2023, 9, 23, 0, 0), 'avg': 52.73913043478261}
# {'_id': datetime.datetime(2023, 4, 5, 0, 0), 'avg': 56.80740740740741}
# {'_id': datetime.datetime(2023, 8, 14, 0, 0), 'avg': 40.8}
# {'_id': datetime.datetime(2023, 2, 7, 0, 0), 'avg': 43.5}
# {'_id': datetime.datetime(2023, 12, 25, 0, 0), 'avg': 54.0}
# {'_id': datetime.datetime(2023, 7, 5, 0, 0), 'avg': 50.333333333333336}
# {'_id': datetime.datetime(2023, 6, 16, 0, 0), 'avg': 42.5}
# {'_id': datetime.datetime(2023, 3, 13, 0, 0), 'avg': 38.5}
# {'_id': datetime.datetime(2023, 10, 28, 0, 0), 'avg': 56.0}
# {'_id': datetime.datetime(2023, 5, 11, 0, 0), 'avg': 58.5}
# {'_id': datetime.datetime(2023, 5, 7, 0, 0), 'avg': 45.0}
# {'_id': datetime.datetime(2023, 7, 31, 0, 0), 'avg': 47.0}
# {'_id': datetime.datetime(2023, 10, 20, 0, 0), 'avg': 50.0}
# {'_id': datetime.datetime(2023, 11, 13, 0, 0), 'avg': 47.0}
# {'_id': datetime.datetime(2023, 5, 22, 0, 0), 'avg': 54.484848484848484}
# {'_id': datetime.datetime(2023, 7, 3, 0, 0), 'avg': 64.0}
# {'_id': datetime.datetime(2023, 5, 24, 0, 0), 'avg': 40.333333333333336}
# {'_id': datetime.datetime(2023, 4, 16, 0, 0), 'avg': 48.72222222222222}
# {'_id': datetime.datetime(2023, 9, 10, 0, 0), 'avg': 44.0}
# {'_id': datetime.datetime(2023, 5, 18, 0, 0), 'avg': 44.142857142857146}
# {'_id': datetime.datetime(2023, 10, 3, 0, 0), 'avg': 69.375}
# {'_id': datetime.datetime(2023, 8, 5, 0, 0), 'avg': 56.291666666666664}
# {'_id': datetime.datetime(2023, 6, 4, 0, 0), 'avg': 61.71186440677966}
# {'_id': datetime.datetime(2023, 3, 17, 0, 0), 'avg': 59.5}
# {'_id': datetime.datetime(2023, 4, 18, 0, 0), 'avg': 53.36615384615384}
# {'_id': datetime.datetime(2023, 4, 14, 0, 0), 'avg': 61.94444444444444}
# {'_id': datetime.datetime(2023, 6, 20, 0, 0), 'avg': 71.16666666666667}
# {'_id': datetime.datetime(2023, 9, 27, 0, 0), 'avg': 49.714285714285715}
# {'_id': datetime.datetime(2023, 3, 10, 0, 0), 'avg': 50.0}
# {'_id': datetime.datetime(2023, 12, 4, 0, 0), 'avg': 52.69565217391305}
# {'_id': datetime.datetime(2023, 5, 4, 0, 0), 'avg': 53.142857142857146}
# {'_id': datetime.datetime(2023, 11, 11, 0, 0), 'avg': 46.25}
# {'_id': datetime.datetime(2023, 6, 22, 0, 0), 'avg': 46.0}
# {'_id': datetime.datetime(2023, 3, 4, 0, 0), 'avg': 58.44444444444444}
# {'_id': datetime.datetime(2023, 4, 4, 0, 0), 'avg': 62.57303370786517}
# {'_id': datetime.datetime(2023, 7, 29, 0, 0), 'avg': 48.0}
# {'_id': datetime.datetime(2023, 3, 25, 0, 0), 'avg': 66.0}
# {'_id': datetime.datetime(2023, 1, 7, 0, 0), 'avg': 30.5}
# {'_id': datetime.datetime(2023, 8, 13, 0, 0), 'avg': 49.0}
# {'_id': datetime.datetime(2023, 5, 14, 0, 0), 'avg': 49.0}
# {'_id': datetime.datetime(2023, 4, 10, 0, 0), 'avg': 49.0}
# {'_id': datetime.datetime(2023, 9, 6, 0, 0), 'avg': 49.0}
# {'_id': datetime.datetime(2023, 9, 3, 0, 0), 'avg': 46.666666666666664}
# {'_id': datetime.datetime(2023, 8, 10, 0, 0), 'avg': 41.0}
# {'_id': datetime.datetime(2023, 5, 8, 0, 0), 'avg': 40.0}
# {'_id': datetime.datetime(2023, 4, 23, 0, 0), 'avg': 53.89473684210526}
# {'_id': datetime.datetime(2023, 11, 5, 0, 0), 'avg': 59.36842105263158}
# {'_id': datetime.datetime(2023, 5, 15, 0, 0), 'avg': 53.950980392156865}
# {'_id': datetime.datetime(2023, 3, 31, 0, 0), 'avg': 48.72727272727273}
# {'_id': datetime.datetime(2023, 10, 17, 0, 0), 'avg': 51.6}
# {'_id': datetime.datetime(2023, 12, 14, 0, 0), 'avg': 70.0}
# {'_id': datetime.datetime(2023, 8, 3, 0, 0), 'avg': 51.5}
# {'_id': datetime.datetime(2023, 6, 5, 0, 0), 'avg': 57.529411764705884}
# {'_id': datetime.datetime(2023, 3, 5, 0, 0), 'avg': 56.796875}
# {'_id': datetime.datetime(2023, 10, 15, 0, 0), 'avg': 72.66666666666667}
# {'_id': datetime.datetime(2023, 10, 18, 0, 0), 'avg': 52.166666666666664}
# {'_id': datetime.datetime(2023, 10, 26, 0, 0), 'avg': 44.6}
# {'_id': datetime.datetime(2023, 12, 21, 0, 0), 'avg': 46.0}
# {'_id': datetime.datetime(2023, 12, 5, 0, 0), 'avg': 51.5}
# {'_id': datetime.datetime(2023, 7, 6, 0, 0), 'avg': 51.857142857142854}
# {'_id': datetime.datetime(2023, 9, 5, 0, 0), 'avg': 42.46153846153846}
# {'_id': datetime.datetime(2023, 6, 13, 0, 0), 'avg': 41.0}
# {'_id': datetime.datetime(2023, 4, 6, 0, 0), 'avg': 52.22222222222222}
# {'_id': datetime.datetime(2023, 7, 14, 0, 0), 'avg': 41.5}
# {'_id': datetime.datetime(2023, 2, 10, 0, 0), 'avg': 43.57142857142857}
# {'_id': datetime.datetime(2023, 4, 15, 0, 0), 'avg': 59.57971014492754}
# {'_id': datetime.datetime(2023, 7, 10, 0, 0), 'avg': 42.0}
# {'_id': datetime.datetime(2023, 4, 7, 0, 0), 'avg': 40.0}
# {'_id': datetime.datetime(2023, 8, 11, 0, 0), 'avg': 45.5}
# {'_id': datetime.datetime(2023, 6, 30, 0, 0), 'avg': 44.333333333333336}
# {'_id': datetime.datetime(2023, 1, 8, 0, 0), 'avg': 58.0}
# {'_id': datetime.datetime(2023, 11, 28, 0, 0), 'avg': 42.0}
# {'_id': datetime.datetime(2023, 8, 4, 0, 0), 'avg': 60.75}
# {'_id': datetime.datetime(2023, 9, 12, 0, 0), 'avg': 58.25}
# {'_id': datetime.datetime(2023, 3, 24, 0, 0), 'avg': 49.0}
# {'_id': datetime.datetime(2023, 9, 24, 0, 0), 'avg': 53.57142857142857}
# {'_id': datetime.datetime(2023, 5, 17, 0, 0), 'avg': 52.0}
# {'_id': datetime.datetime(2023, 6, 18, 0, 0), 'avg': 42.0}
# {'_id': datetime.datetime(2023, 9, 20, 0, 0), 'avg': 63.6}
# {'_id': datetime.datetime(2023, 9, 11, 0, 0), 'avg': 61.3}
# {'_id': datetime.datetime(2023, 11, 4, 0, 0), 'avg': 46.291666666666664}
# {'_id': datetime.datetime(2023, 3, 14, 0, 0), 'avg': 65.6}
# {'_id': datetime.datetime(2023, 11, 29, 0, 0), 'avg': 60.625}
# {'_id': datetime.datetime(2023, 5, 13, 0, 0), 'avg': 58.611111111111114}
# {'_id': datetime.datetime(2023, 6, 14, 0, 0), 'avg': 53.25}
# {'_id': datetime.datetime(2023, 10, 27, 0, 0), 'avg': 50.4}
# {'_id': datetime.datetime(2023, 11, 21, 0, 0), 'avg': 59.0}
# {'_id': datetime.datetime(2023, 1, 5, 0, 0), 'avg': 68.4}
# {'_id': datetime.datetime(2023, 1, 4, 0, 0), 'avg': 46.714285714285715}
# {'_id': datetime.datetime(2023, 12, 27, 0, 0), 'avg': 62.75}
# {'_id': datetime.datetime(2023, 7, 4, 0, 0), 'avg': 50.69230769230769}
# {'_id': datetime.datetime(2023, 12, 15, 0, 0), 'avg': 39.0}
# {'_id': datetime.datetime(2023, 10, 8, 0, 0), 'avg': 63.0}

# %% [markdown]
# ## Task 2.2i
# - Finding the top 10 records with the lowest GHI.

# %%
results = collection.find().sort("GHI_w",1).limit(10)
for result in results:
    pprint(result)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e8'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 9, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e9'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 10, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e4'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 5, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e7'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 8, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e5'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 6, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e3'),
#  'air_temperature_celcius': 24,
#  'date': datetime.datetime(2023, 4, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e1'),
#  'air_temperature_celcius': 15,
#  'date': datetime.datetime(2023, 2, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.02,
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e0'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2022, 12, 31, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e2'),
#  'air_temperature_celcius': 16,
#  'date': datetime.datetime(2023, 3, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.0,
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('6650a2f9f374f529b6ea16e6'),
#  'air_temperature_celcius': 32,
#  'date': datetime.datetime(2023, 7, 1, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'I',
#  'precipitation_value': 0.0,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}

# %% [markdown]
# ## Task 2.2j
# -  Finding the records with a 24-hour precipitation recorded between 0.20 to 0.35.

# %%
results = collection.find({"precipitation_value": {"$gte":0.20, "$lte": 0.35}})
for result in results:
    pprint(result)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('6650a2f9f374f529b6ea16ec'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 1, 13, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('6650a2f9f374f529b6ea1737'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 3, 29, 0, 0),
#  'hotspots': [{'confidence': 69,
#                'datetime': datetime.datetime(2023, 3, 29, 0, 48, 40),
#                'latitude': -34.2648,
#                'longitude': 141.6325,
#                'surface_temperature_celsius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('6650a2f9f374f529b6ea174d'),
#  'air_temperature_celcius': 20,
#  'date': datetime.datetime(2023, 4, 20, 0, 0),
#  'hotspots': [{'confidence': 84,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 44, 20),
#                'latitude': -36.8871,
#                'longitude': 145.1536,
#                'surface_temperature_celsius': 58},
#               {'confidence': 59,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 36),
#                'latitude': -38.4685,
#                'longitude': 146.673,
#                'surface_temperature_celsius': 40},
#               {'confidence': 60,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 34, 10),
#                'latitude': -36.8922,
#                'longitude': 145.1252,
#                'surface_temperature_celsius': 40},
#               {'confidence': 93,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 34, 10),
#                'latitude': -37.769,
#                'longitude': 147.94,
#                'surface_temperature_celsius': 72},
#               {'confidence': 77,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 33, 40),
#                'latitude': -36.0799,
#                'longitude': 146.0784,
#                'surface_temperature_celsius': 50},
#               {'confidence': 88,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 33, 20),
#                'latitude': -36.0829,
#                'longitude': 146.0621,
#                'surface_temperature_celsius': 63},
#               {'confidence': 90,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 50),
#                'latitude': -36.1303,
#                'longitude': 146.3606,
#                'surface_temperature_celsius': 67},
#               {'confidence': 67,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 50),
#                'latitude': -37.7615,
#                'longitude': 147.9169,
#                'surface_temperature_celsius': 45},
#               {'confidence': 63,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -36.8079,
#                'longitude': 145.1409,
#                'surface_temperature_celsius': 42},
#               {'confidence': 85,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -37.7783,
#                'longitude': 147.9284,
#                'surface_temperature_celsius': 60},
#               {'confidence': 79,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -36.8846,
#                'longitude': 145.1679,
#                'surface_temperature_celsius': 52},
#               {'confidence': 80,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -37.2341,
#                'longitude': 149.1736,
#                'surface_temperature_celsius': 53},
#               {'confidence': 63,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -36.9189,
#                'longitude': 147.5603,
#                'surface_temperature_celsius': 52},
#               {'confidence': 98,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -36.1345,
#                'longitude': 146.351,
#                'surface_temperature_celsius': 84},
#               {'confidence': 87,
#                'datetime': datetime.datetime(2023, 4, 20, 4, 32, 30),
#                'latitude': -36.9246,
#                'longitude': 147.5559,
#                'surface_temperature_celsius': 62},
#               {'confidence': 64,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 19),
#                'latitude': -36.085,
#                'longitude': 145.9096,
#                'surface_temperature_celsius': 42},
#               {'confidence': 88,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 18, 40),
#                'latitude': -38.1301,
#                'longitude': 143.9398,
#                'surface_temperature_celsius': 63},
#               {'confidence': 69,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 18, 20),
#                'latitude': -37.7087,
#                'longitude': 145.5499,
#                'surface_temperature_celsius': 45},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 18, 20),
#                'latitude': -36.5865,
#                'longitude': 145.2081,
#                'surface_temperature_celsius': 111},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 17, 10),
#                'latitude': -36.8702,
#                'longitude': 144.0381,
#                'surface_temperature_celsius': 47},
#               {'confidence': 99,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 17, 10),
#                'latitude': -36.1586,
#                'longitude': 145.6666,
#                'surface_temperature_celsius': 85},
#               {'confidence': 74,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 16, 50),
#                'latitude': -37.8672,
#                'longitude': 143.8194,
#                'surface_temperature_celsius': 48},
#               {'confidence': 78,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 15, 30),
#                'latitude': -36.5956,
#                'longitude': 145.206,
#                'surface_temperature_celsius': 51},
#               {'confidence': 77,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 14, 20),
#                'latitude': -37.2197,
#                'longitude': 148.8134,
#                'surface_temperature_celsius': 50},
#               {'confidence': 96,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 14, 10),
#                'latitude': -36.5847,
#                'longitude': 145.1968,
#                'surface_temperature_celsius': 78},
#               {'confidence': 89,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 13, 40),
#                'latitude': -37.6997,
#                'longitude': 145.5519,
#                'surface_temperature_celsius': 64},
#               {'confidence': 61,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 13, 30),
#                'latitude': -37.932,
#                'longitude': 146.1845,
#                'surface_temperature_celsius': 50},
#               {'confidence': 76,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 13, 10),
#                'latitude': -36.6407,
#                'longitude': 144.2957,
#                'surface_temperature_celsius': 50},
#               {'confidence': 63,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 13),
#                'latitude': -36.1569,
#                'longitude': 145.6554,
#                'surface_temperature_celsius': 41},
#               {'confidence': 54,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 13),
#                'latitude': -36.6363,
#                'longitude': 144.3033,
#                'surface_temperature_celsius': 40},
#               {'confidence': 76,
#                'datetime': datetime.datetime(2023, 4, 20, 0, 12, 50),
#                'latitude': -37.2212,
#                'longitude': 148.8262,
#                'surface_temperature_celsius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6650a2f9f374f529b6ea1753'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 4, 26, 0, 0),
#  'hotspots': [{'confidence': 56,
#                'datetime': datetime.datetime(2023, 4, 26, 13, 26, 10),
#                'latitude': -36.5511,
#                'longitude': 146.7819,
#                'surface_temperature_celsius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('6650a2f9f374f529b6ea1772'),
#  'air_temperature_celcius': 14,
#  'date': datetime.datetime(2023, 5, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.35,
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('6650a2f9f374f529b6ea1775'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2023, 5, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('6650a2f9f374f529b6ea1797'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 3, 7, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('6650a2f9f374f529b6ea17af'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 7, 27, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('6650a2f9f374f529b6ea17b9'),
#  'air_temperature_celcius': 9,
#  'date': datetime.datetime(2023, 6, 8, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('6650a2f9f374f529b6ea17cd'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 8, 26, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('6650a2f9f374f529b6ea17d7'),
#  'air_temperature_celcius': 8,
#  'date': datetime.datetime(2023, 5, 9, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.31,
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('6650a2f9f374f529b6ea17d9'),
#  'air_temperature_celcius': 10,
#  'date': datetime.datetime(2023, 7, 9, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('6650a2f9f374f529b6ea17e1'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 9, 15, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('6650a2f9f374f529b6ea17f5'),
#  'air_temperature_celcius': 12,
#  'date': datetime.datetime(2023, 5, 10, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('6650a2f9f374f529b6ea180d'),
#  'air_temperature_celcius': 17,
#  'date': datetime.datetime(2023, 10, 29, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 27.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.24,
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('6650a2f9f374f529b6ea180e'),
#  'air_temperature_celcius': 11,
#  'date': datetime.datetime(2023, 10, 30, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('6650a2f9f374f529b6ea181f'),
#  'air_temperature_celcius': 18,
#  'date': datetime.datetime(2023, 11, 16, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('6650a2f9f374f529b6ea1820'),
#  'air_temperature_celcius': 19,
#  'date': datetime.datetime(2023, 11, 17, 0, 0),
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.28,
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('6650a2f9f374f529b6ea182d'),
#  'air_temperature_celcius': 26,
#  'date': datetime.datetime(2023, 11, 30, 0, 0),
#  'hotspots': [{'confidence': 52,
#                'datetime': datetime.datetime(2023, 11, 30, 23, 25, 57),
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celsius': 47},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 36),
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celsius': 53},
#               {'confidence': 51,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 36),
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celsius': 42},
#               {'confidence': 64,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 36),
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celsius': 42},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 35),
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celsius': 54},
#               {'confidence': 69,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 35),
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celsius': 35},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 35),
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celsius': 49},
#               {'confidence': 61,
#                'datetime': datetime.datetime(2023, 11, 30, 15, 38, 32),
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celsius': 31},
#               {'confidence': 62,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celsius': 33},
#               {'confidence': 64,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celsius': 32},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celsius': 38},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celsius': 42},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celsius': 55},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 15),
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celsius': 65},
#               {'confidence': 100,
#                'datetime': datetime.datetime(2023, 11, 30, 12, 22, 14),
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celsius': 71},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 35),
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celsius': 59},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 35),
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celsius': 50},
#               {'confidence': 98,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celsius': 83},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celsius': 57},
#               {'confidence': 84,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celsius': 61},
#               {'confidence': 99,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celsius': 86},
#               {'confidence': 69,
#                'datetime': datetime.datetime(2023, 11, 30, 4, 34, 57),
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celsius': 48},
#               {'confidence': 60,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 21),
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celsius': 42},
#               {'confidence': 83,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celsius': 58},
#               {'confidence': 87,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celsius': 63},
#               {'confidence': 95,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celsius': 76},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celsius': 56},
#               {'confidence': 73,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celsius': 51},
#               {'confidence': 81,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celsius': 55},
#               {'confidence': 69,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 53),
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celsius': 50},
#               {'confidence': 64,
#                'datetime': datetime.datetime(2023, 11, 30, 0, 20, 49),
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celsius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation_type': 'G',
#  'precipitation_value': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# ## Task 3
# - Optimisation of current database using compound index
#
# - Considering the use cases in task 2, many query operations involve searching by date, filtering by station and aggregation on hotspots
#
# - for high data ingestion rate we wish to minimize index overhead by limiting the number of index
#
# - we can create a compound index that covers multiple query patterns such as between date and station ID since we might want to search for records for a particular station over a specific date period
#
# - we can also create between data and confidence or if queries commonly involve retrieving hotspots based on the date and their confidence level)

# %%
db.collection.createIndex({"date": 1, "station": 1})
db.collection.createIndex({"date": 1, "hotspots.confidence": 1})
